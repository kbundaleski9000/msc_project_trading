# %%
import math
import gymnasium as gym
from gymnasium import spaces
from typing import Dict
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import A2C, SAC
from gym.wrappers import FlattenObservation
from typing import Tuple, Dict, Optional, Any
import matplotlib.pyplot as plt
from stable_baselines3.common.utils import get_linear_fn
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import SubprocVecEnv
import numpy as np
import random
from scipy.optimize import brentq
import torch
import torch.nn as nn
import torch.optim as optim
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
def solve_kyle_model_mine(N: int, sigma2_v: float, sigma2_u: float):
    """
    Calculates the multi-period Kyle model equilibrium using a two-pass algorithm.

    Args:
        N (int): The total number of trading periods.
        sigma2_v (float): The initial variance of the asset's value (Sigma_0).
        sigma2_u (float): The variance of the noise trader's orders.

    Returns:
        dict: A dictionary containing the numpy arrays for each equilibrium
              parameter sequence: 'Sigma', 'Lambda', 'Beta', and 'Alpha'.
    """
    # Helper for readability
    sigma_u = np.sqrt(sigma2_u)

    # --- ⏪ PASS 1: BACKWARD ITERATION for h_n ---
    # h_n = Sigma_n / Sigma_{n-1}
    h = np.zeros(N)
    h[-1] = 0.5  # Terminal condition for the last period (n=N)

    # Iterate backwards from n = N-1 down to n=1
    for n in reversed(range(N - 1)):
        # Calculate theta_{n+1} from the known h_{n+1}
        h_next = h[n + 1]
        theta_next = np.sqrt(h_next / (1 - h_next))

        # Define the function whose root h_n we need to find
        # f(h_n) = theta_{n+1} - (2*h_n - 1) / (h_n * sqrt(1-h_n)) = 0
        def root_func(h_n):
            if h_n <= 0.5 or h_n >= 1.0: # Numerical stability
                return np.inf
            return theta_next - (2 * h_n - 1) / (h_n * np.sqrt(1 - h_n))

        # Find the root h_n in the interval (0.5, 1.0)
        # brentq is a robust and efficient choice here.
        h[n] = brentq(root_func, 0.5 + 1e-9, 1.0 - 1e-9)

    # --- ⏩ PASS 2: FORWARD ITERATION for equilibrium parameters ---
    Sigma = np.zeros(N + 1)
    Lambda = np.zeros(N)
    Beta = np.zeros(N)
    Alpha = np.zeros(N)

    Sigma[0] = sigma2_v # Initial condition

    # Iterate forward from n=1 to N
    for n in range(N):
        # Update variance using the pre-calculated h_n
        Sigma[n + 1] = h[n] * Sigma[n]

        # Calculate the equilibrium parameters for period n
        Lambda[n] = np.sqrt((1 - h[n]) * Sigma[n + 1]) / sigma_u
        Beta[n] = (np.sqrt(1 - h[n]) * sigma_u) / np.sqrt(Sigma[n + 1])
        Alpha[n] = (sigma_u / (2 * np.sqrt(Sigma[n]))) * np.sqrt(h[n] / (1 - h[n]))
    
    return Beta, Lambda

# %%
def equilibrium_insider_action(v, mean_v, beta):
    return beta * (v - mean_v)

def equilibrium_market_maker_action(y, mean_v, lambda_):
    return mean_v + lambda_ * y

# %%
class KyleModelEnv(gym.Env):
    metadata = {'render_modes': ['human']}

    def __init__(self, sigma_v=2.0, sigma_u=1.0, p0=0.5, T=25, gamma=0.95, action_scaling = 5):
        super(KyleModelEnv, self).__init__()
        
        self.action_scaling = action_scaling
        self.sigma_v = sigma_v
        self.sigma_u = sigma_u
        self.p0 = p0
        self.T = T
        self.u = 0.0
        self.gamma = gamma
        self.actual_actions = []
        self.beta = np.zeros(self.T)
        self.lmbd = np.zeros(self.T)
        self.alpha = np.zeros(self.T)
        self.h = np.zeros(self.T)
        self.Sigma = np.zeros(self.T)
        self.delta = np.zeros(self.T)
        self.history_price = np.zeros(self.T, dtype=np.float32)
        self.history_price[0] = self.p0
        self.solve_kyle_model()

        # Define action and observation spaces
        self.action_space = spaces.Box(
            low=-1.0,
            high=1.0,
            shape=(1,),
            dtype=np.float32
        )

        self.observation_space = spaces.Dict({
            'v': spaces.Box(low=-np.inf, high=np.inf, shape=(1,), dtype=np.float32),
            'history_price': spaces.Box(low=-np.inf, high=np.inf, shape=(self.T,), dtype=np.float32),
            'sigma_v': spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32),
            'sigma_u': spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32),
            'time': spaces.Box(low=0, high=self.T, shape=(1,), dtype=np.float32)
        })

        self.reset()

    def reset(self, seed=None, options=None):
        """Reset environment to initial state"""
        super().reset(seed=seed)

        self.v = np.random.normal(self.p0, self.sigma_v)  # True asset value
        self.p = self.p0
        self.t = 0
        self.solve_kyle_model()
        self.history_price = np.zeros(self.T, dtype=np.float32)
        self.history_price[0] = self.p

        obs = self._get_insider_obs()
        info = {}
        return obs, info  # Gymnasium requires (obs, info)

    def _get_insider_obs(self):
        return {
            'v': np.array([self.v], dtype=np.float32),
            'history_price': self.history_price.reshape(-1,),
            'sigma_v': np.array([self.sigma_v], dtype=np.float32),
            'sigma_u': np.array([self.sigma_u], dtype=np.float32),
            'time': np.array([self.t/self.T], dtype=np.float32)
        }
    
    def solve_kyle_model(self):
        """
        Calculates the multi-period Kyle model equilibrium using a two-pass algorithm.

        Args:
            N (int): The total number of trading periods.
            sigma2_v (float): The initial variance of the asset's value (Sigma_0).
            sigma2_u (float): The variance of the noise trader's orders.

        Returns:
            dict: A dictionary containing the numpy arrays for each equilibrium
                parameter sequence: 'Sigma', 'Lambda', 'Beta', and 'Alpha'.
        """
        # Helper for readability
        sigma_u = np.sqrt(self.sigma_u)

        # --- ⏪ PASS 1: BACKWARD ITERATION for h_n ---
        # h_n = Sigma_n / Sigma_{n-1}
        h = np.zeros(self.T)
        h[-1] = 0.5  # Terminal condition for the last period (n=N)

        # Iterate backwards from n = N-1 down to n=1
        for n in reversed(range(self.T - 1)):
            # Calculate theta_{n+1} from the known h_{n+1}
            h_next = h[n + 1]
            theta_next = np.sqrt(h_next / (1 - h_next))

            # Define the function whose root h_n we need to find
            # f(h_n) = theta_{n+1} - (2*h_n - 1) / (h_n * sqrt(1-h_n)) = 0
            def root_func(h_n):
                if h_n <= 0.5 or h_n >= 1.0: # Numerical stability
                    return np.inf
                return theta_next - (2 * h_n - 1) / (h_n * np.sqrt(1 - h_n))

            # Find the root h_n in the interval (0.5, 1.0)
            # brentq is a robust and efficient choice here.
            h[n] = brentq(root_func, 0.5 + 1e-9, 1.0 - 1e-9)

        # --- ⏩ PASS 2: FORWARD ITERATION for equilibrium parameters ---
        Sigma = np.zeros(self.T + 1)
        Lambda = np.zeros(self.T)
        Beta = np.zeros(self.T)
        Alpha = np.zeros(self.T)

        Sigma[0] = self.sigma_v # Initial condition

        # Iterate forward from n=1 to N
        for n in range(self.T):
            # Update variance using the pre-calculated h_n
            Sigma[n + 1] = h[n] * Sigma[n]

            # Calculate the equilibrium parameters for period n
            Lambda[n] = np.sqrt((1 - h[n]) * Sigma[n + 1]) / sigma_u
            Beta[n] = (np.sqrt(1 - h[n]) * sigma_u) / np.sqrt(Sigma[n + 1])
            Alpha[n] = (sigma_u / (2 * np.sqrt(Sigma[n]))) * np.sqrt(h[n] / (1 - h[n]))
        
        self.beta = Beta
        self.lmbd = Lambda
        self.alpha = Alpha
        self.h = h
        self.Sigma = Sigma

        self.delta[self.T-1] = 0  # Terminal condition
        
        for n in reversed(range(1, self.T-1)):
            self.delta[n-1] = self.delta[n] + self.alpha[n] * ( self.lmbd[n] ** 2 ) * self.sigma_u

    def step(self, action):
        """Execute one step"""
        if self.t >= self.T:
            raise ValueError("Episode has already ended")

        scaled_action = action * self.action_scaling
        self.actual_actions.append(scaled_action[0])

        x = scaled_action[0]
        self.u = np.random.normal(0, self.sigma_u)
        y = x + self.u
        p_new = self.p + self.lmbd[self.t] * y


        insider_profit = (self.v - p_new) * x

        # Update state
        self.p = p_new
        self.t += 1

        if self.t < self.T:
            self.history_price[self.t] = self.p

        terminated = (self.t >= self.T)  # natural end
        truncated = False  # No time/truncation logic here

        obs = self._get_insider_obs()
        info = {}

        return obs, insider_profit, terminated, truncated, info



# Example usage with Gym interface
print("Testing Kyle model with Gym interface")

env_insider = KyleModelEnv()

# Initialize the model

clip_range_schedule = get_linear_fn(start=0.4, end=0.2, end_fraction=0.8)




policy_kwargs = dict(
    net_arch=dict(pi=[128,128], vf=[128,128])  # Separate networks
)

model_insider = PPO(
    "MultiInputPolicy",
    env_insider,
    verbose = 1,
    learning_rate = 0.0004,
    clip_range = clip_range_schedule,
    policy_kwargs=policy_kwargs

)
# Out:
# Testing Kyle model with Gym interface
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Uzh\project\projectvenv\Lib\site-packages\stable_baselines3\common\utils.py:195: UserWarning: get_linear_fn() is deprecated, please use LinearSchedule() instead
#   warnings.warn("get_linear_fn() is deprecated, please use LinearSchedule() instead")

# %%
action_scaling = 5

# %%
model_insider.learn(total_timesteps=40_000)

# Test trained agent
obs = env_insider.reset()
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 9.98     |
# | time/              |          |
# |    fps             | 2341     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25         |
# |    ep_rew_mean          | 8.59       |
# | time/                   |            |
# |    fps                  | 1613       |
# |    iterations           | 2          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.07469512 |
# |    clip_fraction        | 0.151      |
# |    clip_range           | 0.387      |
# |    entropy_loss         | 0.773      |
# |    explained_variance   | 0.723      |
# |    learning_rate        | 0.0004     |
# |    loss                 | 2.32       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0184    |
# |    std                  | 0.11       |
# |    value_loss           | 6.26       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 5.72        |
# | time/                   |             |
# |    fps                  | 1470        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.054335155 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.374       |
# |    entropy_loss         | 0.796       |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 1.86        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0137     |
# |    std                  | 0.108       |
# |    value_loss           | 5.16        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 8.72        |
# | time/                   |             |
# |    fps                  | 1410        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.059635848 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.362       |
# |    entropy_loss         | 0.834       |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0004      |
# |    loss                 | 1.38        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.103       |
# |    value_loss           | 4.07        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25        |
# |    ep_rew_mean          | 8.41      |
# | time/                   |           |
# |    fps                  | 1376      |
# |    iterations           | 5         |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0524394 |
# |    clip_fraction        | 0.175     |
# |    clip_range           | 0.349     |
# |    entropy_loss         | 0.868     |
# |    explained_variance   | 0.73      |
# |    learning_rate        | 0.0004    |
# |    loss                 | 9.08      |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0144   |
# |    std                  | 0.1       |
# |    value_loss           | 6.58      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25         |
# |    ep_rew_mean          | 7.86       |
# | time/                   |            |
# |    fps                  | 1355       |
# |    iterations           | 6          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.06552639 |
# |    clip_fraction        | 0.167      |
# |    clip_range           | 0.336      |
# |    entropy_loss         | 0.895      |
# |    explained_variance   | 0.578      |
# |    learning_rate        | 0.0004     |
# |    loss                 | 2.12       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0183    |
# |    std                  | 0.0971     |
# |    value_loss           | 7.08       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25        |
# |    ep_rew_mean          | 7.62      |
# | time/                   |           |
# |    fps                  | 1333      |
# |    iterations           | 7         |
# |    time_elapsed         | 10        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0887759 |
# |    clip_fraction        | 0.199     |
# |    clip_range           | 0.323     |
# |    entropy_loss         | 0.935     |
# |    explained_variance   | 0.654     |
# |    learning_rate        | 0.0004    |
# |    loss                 | 2.82      |
# |    n_updates            | 460       |
# |    policy_gradient_loss | -0.0135   |
# |    std                  | 0.093     |
# |    value_loss           | 5.57      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 7.35        |
# | time/                   |             |
# |    fps                  | 1279        |
# |    iterations           | 8           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.050293334 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.31        |
# |    entropy_loss         | 0.963       |
# |    explained_variance   | 0.702       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 1.71        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0106     |
# |    std                  | 0.0915      |
# |    value_loss           | 4.18        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25         |
# |    ep_rew_mean          | 6.61       |
# | time/                   |            |
# |    fps                  | 1275       |
# |    iterations           | 9          |
# |    time_elapsed         | 14         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.07559469 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.298      |
# |    entropy_loss         | 0.978      |
# |    explained_variance   | 0.613      |
# |    learning_rate        | 0.0004     |
# |    loss                 | 1.13       |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0192    |
# |    std                  | 0.0903     |
# |    value_loss           | 4.74       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25         |
# |    ep_rew_mean          | 8.59       |
# | time/                   |            |
# |    fps                  | 1161       |
# |    iterations           | 10         |
# |    time_elapsed         | 17         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.07979372 |
# |    clip_fraction        | 0.176      |
# |    clip_range           | 0.285      |
# |    entropy_loss         | 0.984      |
# |    explained_variance   | 0.593      |
# |    learning_rate        | 0.0004     |
# |    loss                 | 1.86       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00576   |
# |    std                  | 0.0904     |
# |    value_loss           | 6.15       |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25        |
# |    ep_rew_mean          | 7.43      |
# | time/                   |           |
# |    fps                  | 1133      |
# |    iterations           | 11        |
# |    time_elapsed         | 19        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0497316 |
# |    clip_fraction        | 0.194     |
# |    clip_range           | 0.272     |
# |    entropy_loss         | 0.989     |
# |    explained_variance   | 0.719     |
# |    learning_rate        | 0.0004    |
# |    loss                 | 2.08      |
# |    n_updates            | 500       |
# |    policy_gradient_loss | -0.0107   |
# |    std                  | 0.0891    |
# |    value_loss           | 6.14      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 6.76        |
# | time/                   |             |
# |    fps                  | 1142        |
# |    iterations           | 12          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.036388285 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.259       |
# |    entropy_loss         | 0.995       |
# |    explained_variance   | 0.645       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 2.48        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00736    |
# |    std                  | 0.0896      |
# |    value_loss           | 5.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 6.67        |
# | time/                   |             |
# |    fps                  | 1150        |
# |    iterations           | 13          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.043901246 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.246       |
# |    entropy_loss         | 1           |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 3.78        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00921    |
# |    std                  | 0.0884      |
# |    value_loss           | 5.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 9.2         |
# | time/                   |             |
# |    fps                  | 1158        |
# |    iterations           | 14          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.039322063 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.234       |
# |    entropy_loss         | 1.02        |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 1.91        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00487    |
# |    std                  | 0.0873      |
# |    value_loss           | 5.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 8.91        |
# | time/                   |             |
# |    fps                  | 1164        |
# |    iterations           | 15          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.029248051 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.221       |
# |    entropy_loss         | 1.03        |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 2.7         |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00272    |
# |    std                  | 0.0858      |
# |    value_loss           | 7.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 6.45        |
# | time/                   |             |
# |    fps                  | 1168        |
# |    iterations           | 16          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.043058828 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.208       |
# |    entropy_loss         | 1.05        |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 1.78        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.000878   |
# |    std                  | 0.0841      |
# |    value_loss           | 5.57        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 25        |
# |    ep_rew_mean          | 6.89      |
# | time/                   |           |
# |    fps                  | 1173      |
# |    iterations           | 17        |
# |    time_elapsed         | 29        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0374856 |
# |    clip_fraction        | 0.261     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 1.06      |
# |    explained_variance   | 0.552     |
# |    learning_rate        | 0.0004    |
# |    loss                 | 2.11      |
# |    n_updates            | 560       |
# |    policy_gradient_loss | -0.00629  |
# |    std                  | 0.0839    |
# |    value_loss           | 4.71      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25         |
# |    ep_rew_mean          | 6.82       |
# | time/                   |            |
# |    fps                  | 1178       |
# |    iterations           | 18         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02234276 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.07       |
# |    explained_variance   | 0.647      |
# |    learning_rate        | 0.0004     |
# |    loss                 | 2.23       |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.00612   |
# |    std                  | 0.0817     |
# |    value_loss           | 5.11       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25         |
# |    ep_rew_mean          | 6.8        |
# | time/                   |            |
# |    fps                  | 1182       |
# |    iterations           | 19         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.03444563 |
# |    clip_fraction        | 0.269      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 1.09       |
# |    explained_variance   | 0.549      |
# |    learning_rate        | 0.0004     |
# |    loss                 | 3.41       |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.000821  |
# |    std                  | 0.081      |
# |    value_loss           | 5.17       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 6.85        |
# | time/                   |             |
# |    fps                  | 1185        |
# |    iterations           | 20          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.040263385 |
# |    clip_fraction        | 0.288       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.11        |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 1.02        |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00308    |
# |    std                  | 0.0787      |
# |    value_loss           | 4.89        |
# -----------------------------------------

# %%
obs, info = env_insider.reset()
done = False



while not done:
    action, _ = model_insider.predict(obs, deterministic=True) 

    obs_tensor = model_insider.policy.obs_to_tensor(obs)[0]
    dist = model_insider.policy.get_distribution(obs_tensor)

    action_mean = dist.distribution.mean.detach().cpu().numpy().flatten()
    action_std  = dist.distribution.stddev.detach().cpu().numpy().flatten()
    action *= action_scaling
    obs, reward, terminated, truncated, info = env_insider.step(action)
    done = terminated or truncated

    print(f"Action distribution after training: mean={action_mean*5}, std={action_std}")

    print(f"Step: {env_insider.t}, Action: {action}, Reward: {reward} , env u : {env_insider.u}")
# Out:
# Action distribution after training: mean=[0.90522337], std=[0.07809322]
# Step: 1, Action: [0.90522337], Reward: 4.762701824002779 , env u : -1.9543097105309102
# Action distribution after training: mean=[0.60540295], std=[0.07809322]
# Step: 2, Action: [0.60540295], Reward: 1.5352501518329968 , env u : -0.9490344653440695
# Action distribution after training: mean=[0.59252864], std=[0.07809322]
# Step: 3, Action: [0.59252864], Reward: -0.5490138217411807 , env u : -0.32256886995724116
# Action distribution after training: mean=[0.32870018], std=[0.07809322]
# Step: 4, Action: [0.32870018], Reward: -0.7115001015371838 , env u : -0.6994678137909254
# Action distribution after training: mean=[0.14109194], std=[0.07809322]
# Step: 5, Action: [0.14109194], Reward: -0.29037905228157984 , env u : -0.786677472733492
# Action distribution after training: mean=[-0.26790872], std=[0.07809322]
# Step: 6, Action: [-0.26790872], Reward: 0.3753239679651891 , env u : 0.8383722146297866
# Action distribution after training: mean=[0.09679206], std=[0.07809322]
# Step: 7, Action: [0.09679206], Reward: -0.18373674393590797 , env u : -0.10464013980652291
# Action distribution after training: mean=[0.15772465], std=[0.07809322]
# Step: 8, Action: [0.15772465], Reward: -0.4835651329606842 , env u : 0.10204738018212946
# Action distribution after training: mean=[0.07485189], std=[0.07809322]
# Step: 9, Action: [0.07485189], Reward: -0.16621069841194303 , env u : -1.01918742254579
# Action distribution after training: mean=[0.17826945], std=[0.07809322]
# Step: 10, Action: [0.17826945], Reward: -0.28168928553755795 , env u : -1.379985371701206
# Action distribution after training: mean=[-0.35332823], std=[0.07809322]
# Step: 11, Action: [-0.35332823], Reward: -0.19637140135345485 , env u : 0.13659085641949723
# Action distribution after training: mean=[-0.00278979], std=[0.07809322]
# Step: 12, Action: [-0.00278979], Reward: -0.006846500445499394 , env u : -1.435124164679631
# Action distribution after training: mean=[0.09295948], std=[0.07809322]
# Step: 13, Action: [0.09295948], Reward: 0.14553231413290277 , env u : 0.21366724153653688
# Action distribution after training: mean=[0.0220234], std=[0.07809322]
# Step: 14, Action: [0.0220234], Reward: 0.02862742434607605 , env u : 0.09280804220533649
# Action distribution after training: mean=[0.01093753], std=[0.07809322]
# Step: 15, Action: [0.01093753], Reward: 0.0092037357037605 , env u : 0.295566071477666
# Action distribution after training: mean=[0.41185334], std=[0.07809322]
# Step: 16, Action: [0.41185334], Reward: 0.18525761260973622 , env u : -1.7598299924811132
# Action distribution after training: mean=[0.43853417], std=[0.07809322]
# Step: 17, Action: [0.43853417], Reward: -1.3122269888225027 , env u : 0.4407442598231263
# Action distribution after training: mean=[0.42099065], std=[0.07809322]
# Step: 18, Action: [0.42099065], Reward: -2.9069961267128988 , env u : 0.8914436621836838
# Action distribution after training: mean=[0.2999664], std=[0.07809322]
# Step: 19, Action: [0.2999664], Reward: -3.3550990049031757 , env u : 1.7819816821002072
# Action distribution after training: mean=[0.14865734], std=[0.07809322]
# Step: 20, Action: [0.14865734], Reward: -1.7226523641520735 , env u : -0.4335240856187421
# Action distribution after training: mean=[0.11111051], std=[0.07809322]
# Step: 21, Action: [0.11111051], Reward: -1.400010747666128 , env u : 0.22450501006510182
# Action distribution after training: mean=[-1.0127335], std=[0.07809322]
# Step: 22, Action: [-1.0127335], Reward: 6.739404563989984 , env u : 0.45658779636105823
# Action distribution after training: mean=[-0.67662424], std=[0.07809322]
# Step: 23, Action: [-0.67662424], Reward: 1.0952431225971495 , env u : -0.5606416749647806
# Action distribution after training: mean=[-0.81645656], std=[0.07809322]
# Step: 24, Action: [-0.81645656], Reward: -3.511985223077044 , env u : -0.6768643068418516
# Action distribution after training: mean=[-0.8734372], std=[0.07809322]
# Step: 25, Action: [-0.8734372], Reward: -9.089833768785464 , env u : -1.0803915488596791

# %%
def evaluate_agent_actions_multiperiod(model, env, n_stdevs, action_scaling=5):
    obs, info = env.reset()

    steps = env.T
    optimal_insider_actions = np.zeros((steps))
    optimal_market_maker_actions = np.zeros((steps))

    trained_insider_actions = np.zeros((steps))
    trained_market_maker_actions = np.zeros((steps))

    values = np.linspace(1, steps, steps)
    beta, lmbd = solve_kyle_model_mine(steps, env.sigma_v, env.sigma_u)

    p0 = env.p0
    v = env.v

    total_reward_model = np.zeros((steps))
    total_reward_optimal = np.zeros((steps))

        

    for i in range(len(values)):
        
        action, _ = model_insider.predict(obs, deterministic=True) 
        obs, reward, terminated, truncated, info = env_insider.step(action)
        trained_insider_actions[i] = action * action_scaling 
        optimal_insider_actions[i] = equilibrium_insider_action(v, p0, beta[i])
        u = env.u
        y = optimal_insider_actions[i] + u
        total_reward_model[i] = reward
        

        trained_market_maker_actions[i] = env.p
        optimal_market_maker_actions[i] = equilibrium_market_maker_action(y, p0, lmbd[i])
        p0 = lmbd[i] * y + p0
        total_reward_optimal[i] = (v - optimal_market_maker_actions[i]) * optimal_insider_actions[i]

        

    env.reset()

    # plot: 2 subplots. one for insider (values vs action) and one for market maker (order vs action)
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 5))
    
    # Insider subplot
    ax1.plot(values, optimal_insider_actions, label="Optimal", linestyle='--')
    ax1.plot(values, trained_insider_actions, label="Trained", linestyle='-')
    ax1.axvline(x=env.p0, color='black', linestyle=':', alpha=0.5)
    ax1.axhline(y=0, color='black', linestyle=':', alpha=0.5)
    ax1.set_title("Insider Action")
    ax1.set_xlabel("Timestep t")
    ax1.set_ylabel("Action x")
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # Market Maker subplot
    ax2.plot(values, optimal_market_maker_actions, label="Optimal", linestyle='--')
    ax2.plot(values, trained_market_maker_actions, label="Trained", linestyle='-')
    ax2.axvline(x=0, color='black', linestyle=':', alpha=0.5)
    ax2.axhline(y=env.p0, color='black', linestyle=':', alpha=0.5)
    ax2.set_title("Market Maker Action")
    ax2.set_xlabel("Timestep t")
    ax2.set_ylabel("Price p")
    ax2.legend()
    ax2.grid(True, alpha=0.3)

        # Insider Reward subplot
    ax3.plot(values, total_reward_optimal, label="Optimal", linestyle='--')
    ax3.plot(values, total_reward_model, label="Trained", linestyle='-')
    ax3.axvline(x=env.p0, color='black', linestyle=':', alpha=0.5)
    ax3.axhline(y=0, color='black', linestyle=':', alpha=0.5)
    ax3.set_title("Insider Action")
    ax3.set_xlabel("Timestep t")
    ax3.set_ylabel("Action x")
    ax3.legend()
    ax3.grid(True, alpha=0.3)
    
    
    plt.tight_layout()
    plt.show() 

    return total_reward_model, total_reward_optimal

# %%
trm, tro = evaluate_agent_actions_multiperiod(model_insider, env_insider, n_stdevs=3, action_scaling=action_scaling)
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_1844\1112799624.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   trained_insider_actions[i] = action * action_scaling

# %%
class KyleModelEnvMM(gym.Env):
    metadata = {'render_modes': ['human']}

    def __init__(self, sigma_v=2.0, sigma_u=1.0, p0=0.5, T=25, gamma=0.9, action_scaling = 5):
        super(KyleModelEnvMM, self).__init__()

        self.action_scaling = action_scaling
        self.sigma_v = sigma_v
        self.sigma_u = sigma_u
        self.p0 = p0
        self.T = T
        self.gamma = gamma
        self.actual_actions = []
        self.beta = np.zeros(self.T)
        self.lmbd = np.zeros(self.T)
        self.alpha = np.zeros(self.T)
        self.h = np.zeros(self.T)
        self.Sigma = np.zeros(self.T)
        self.delta = np.zeros(self.T)
        self.solve_kyle_model()

        # Define action space (Market Maker's price guess)
        self.action_space = spaces.Box(
            low=-1.0,
            high=1.0,
            shape=(1,),
            dtype=np.float32
        )

        # Observation space for the market maker
        self.observation_space = spaces.Dict({
            'y': spaces.Box(low=-np.inf, high=np.inf, shape=(1,), dtype=np.float32),
            'p': spaces.Box(low=-np.inf, high=np.inf, shape=(1,), dtype=np.float32),
            'sigma_v': spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32),
            'sigma_u': spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32),
            'time': spaces.Box(low=0, high=self.T, shape=(1,), dtype=np.float32)
        })

    def solve_kyle_model(self):
        """
        Calculates the multi-period Kyle model equilibrium using a two-pass algorithm.

        Args:
            N (int): The total number of trading periods.
            sigma2_v (float): The initial variance of the asset's value (Sigma_0).
            sigma2_u (float): The variance of the noise trader's orders.

        Returns:
            dict: A dictionary containing the numpy arrays for each equilibrium
                parameter sequence: 'Sigma', 'Lambda', 'Beta', and 'Alpha'.
        """
        # Helper for readability
        sigma_u = np.sqrt(self.sigma_u)

        # --- ⏪ PASS 1: BACKWARD ITERATION for h_n ---
        # h_n = Sigma_n / Sigma_{n-1}
        h = np.zeros(self.T)
        h[-1] = 0.5  # Terminal condition for the last period (n=N)

        # Iterate backwards from n = N-1 down to n=1
        for n in reversed(range(self.T - 1)):
            # Calculate theta_{n+1} from the known h_{n+1}
            h_next = h[n + 1]
            theta_next = np.sqrt(h_next / (1 - h_next))

            # Define the function whose root h_n we need to find
            # f(h_n) = theta_{n+1} - (2*h_n - 1) / (h_n * sqrt(1-h_n)) = 0
            def root_func(h_n):
                if h_n <= 0.5 or h_n >= 1.0: # Numerical stability
                    return np.inf
                return theta_next - (2 * h_n - 1) / (h_n * np.sqrt(1 - h_n))

            # Find the root h_n in the interval (0.5, 1.0)
            # brentq is a robust and efficient choice here.
            h[n] = brentq(root_func, 0.5 + 1e-9, 1.0 - 1e-9)

        # --- ⏩ PASS 2: FORWARD ITERATION for equilibrium parameters ---
        Sigma = np.zeros(self.T + 1)
        Lambda = np.zeros(self.T)
        Beta = np.zeros(self.T)
        Alpha = np.zeros(self.T)

        Sigma[0] = self.sigma_v # Initial condition

        # Iterate forward from n=1 to N
        for n in range(self.T):
            # Update variance using the pre-calculated h_n
            Sigma[n + 1] = h[n] * Sigma[n]

            # Calculate the equilibrium parameters for period n
            Lambda[n] = np.sqrt((1 - h[n]) * Sigma[n + 1]) / sigma_u
            Beta[n] = (np.sqrt(1 - h[n]) * sigma_u) / np.sqrt(Sigma[n + 1])
            Alpha[n] = (sigma_u / (2 * np.sqrt(Sigma[n]))) * np.sqrt(h[n] / (1 - h[n]))
        
        self.beta = Beta
        self.lmbd = Lambda
        self.alpha = Alpha
        self.h = h
        self.Sigma = Sigma

        self.delta[self.T-1] = 0  # Terminal condition
        
        for n in reversed(range(1, self.T-1)):
            self.delta[n-1] = self.delta[n] + self.alpha[n] * ( self.lmbd[n] ** 2 ) * self.sigma_u

    def reset(self, *, seed=None, options=None):
        """Reset the environment to initial state"""
        super().reset(seed=seed)

        # True asset value is drawn from N(p0, sigma_v^2)
        self.v = np.random.normal(self.p0, self.sigma_v)

        # Initialize state variables
        self.p = self.p0
        self.t = 0

        # Generate initial observation
        self.x = self.beta[self.t] * (self.v - self.p)
        self.u = np.random.normal(0, self.sigma_u)
        self.y = self.x + self.u

        obs = self._get_mm_obs()
        info = {}
        return obs, info  # Gymnasium requires (obs, info)

    def _get_mm_obs(self) -> Dict[str, np.ndarray]:
        return {
            'y': np.array([self.y], dtype=np.float32),
            'p': np.array([self.p], dtype=np.float32),
            'sigma_v': np.array([self.sigma_v], dtype=np.float32),
            'sigma_u': np.array([self.sigma_u], dtype=np.float32),
            'time': np.array([self.t/self.T], dtype=np.float32)
        }

    def step(self, action):
        """Execute one step of the environment"""
        if self.t >= self.T:
            raise ValueError("Episode has already ended")

        # Scale PPO's normalized action to market price guess
        scaled_action = action[0] * self.action_scaling
        self.actual_actions.append(scaled_action)

        # Market maker's loss function (negative MSE against true value)
        mm_loss = (scaled_action - self.v) * self.y
        self.p = scaled_action

        # Update timestep
        self.t += 1

        if self.t < self.T:
            self.x = self.beta[self.t] * (self.v - self.p)
            self.u = np.random.normal(0, self.sigma_u)
            self.y = self.x + self.u

        terminated = (self.t >= self.T)  # natural termination
        truncated = False  # no time truncation here

        obs = self._get_mm_obs()
        info = {}

        return obs, mm_loss, terminated, truncated, info

# Example usage with Gym interface
print("Testing Kyle model with Gym interface")

env_mm = KyleModelEnvMM()

# Initialize the model

clip_range_schedule = get_linear_fn(start=0.3, end=0.2, end_fraction=0.9)




policy_kwargs = dict(
    net_arch=dict(pi=[128, 128], vf=[128, 128])  # Separate networks
)


model_mm = PPO(
    "MultiInputPolicy",
    env_mm,
    verbose = 1,
    learning_rate = 0.00025,
    clip_range = clip_range_schedule,
    policy_kwargs=policy_kwargs,
    vf_coef = 0.1
    

)
# Out:
# Testing Kyle model with Gym interface
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model_mm.learn(total_timesteps=5)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -37.9    |
# | time/              |          |
# |    fps             | 831      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------

# %%
actions = []
prices = []
rewards = []

obs, info = env_mm.reset()
done = False
print(env_mm.v)
print(f"Env x {env_mm.x} Env u {env_mm.u}")
print(f"Obs : {obs}")

while not done:
    action, _ = model_mm.predict(obs)

    obs, reward, terminated, truncated, info = env_mm.step(action)
    action *= 5

    print(f"Env x {env_mm.x} Env u {env_mm.u}")
    print(f"Obs : {obs}")
    print(f"Step: {env_mm.t}, Action: {action}, Reward: {reward}")

    done = terminated or truncated
# Out:
# 3.1018212604151576
# Env x 0.3538949479991064 Env u -1.08984100444552
# Obs : {'y': array([-0.73594606], dtype=float32), 'p': array([0.5], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.], dtype=float32)}
# Env x 0.6637119430575011 Env u 0.7221777661874235
# Obs : {'y': array([1.3858898], dtype=float32), 'p': array([-1.5972084], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.04], dtype=float32)}
# Step: 1, Action: [-1.5972084], Reward: 3.4582321896503645
# Env x 0.9173483008961183 Env u -0.4645901590644471
# Obs : {'y': array([0.45275813], dtype=float32), 'p': array([-3.14304], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.08], dtype=float32)}
# Step: 2, Action: [-3.14304], Reward: -8.654688770112298
# Env x 1.2398151852350308 Env u -0.6736965084443131
# Obs : {'y': array([0.56611866], dtype=float32), 'p': array([-5.], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.12], dtype=float32)}
# Step: 3, Action: [-5.], Reward: -3.66816539684604
# Env x 0.4098803769741188 Env u 0.49384821953548874
# Obs : {'y': array([0.9037286], dtype=float32), 'p': array([0.5353764], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.16], dtype=float32)}
# Step: 4, Action: [0.5353764], Reward: -1.4529123760175326
# Env x 0.9223839704348974 Env u 0.24521286821292207
# Obs : {'y': array([1.1675968], dtype=float32), 'p': array([-2.4211535], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.2], dtype=float32)}
# Step: 5, Action: [-2.4211535], Reward: -4.991270416349061
# Env x 0.7410442034671435 Env u 0.03403395867820577
# Obs : {'y': array([0.7750782], dtype=float32), 'p': array([-1.1321075], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.24], dtype=float32)}
# Step: 6, Action: [-1.1321075], Reward: -4.943521742318635
# Env x 1.1100023292269874 Env u 1.7705504705291941
# Obs : {'y': array([2.8805528], dtype=float32), 'p': array([-2.935073], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.28], dtype=float32)}
# Step: 7, Action: [-2.935073], Reward: -4.679064586142622
# Env x 0.2923185286605791 Env u -0.6992425713299103
# Obs : {'y': array([-0.40692404], dtype=float32), 'p': array([1.592533], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.32], dtype=float32)}
# Step: 8, Action: [1.592533], Reward: -4.347584326515038
# Env x -0.388415057991088 Env u -0.7940496751284651
# Obs : {'y': array([-1.1824647], dtype=float32), 'p': array([5.], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.36], dtype=float32)}
# Step: 9, Action: [5.], Reward: -0.7724145974515783
# Env x 1.6883618040535704 Env u -0.32829074556697024
# Obs : {'y': array([1.3600711], dtype=float32), 'p': array([-4.6815534], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.4], dtype=float32)}
# Step: 10, Action: [-4.6815534], Reward: 9.203566189542682
# Env x 1.0316196399619304 Env u -0.48164038899722955
# Obs : {'y': array([0.54997927], dtype=float32), 'p': array([-1.3673136], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.44], dtype=float32)}
# Step: 11, Action: [-1.3673136], Reward: -6.078340908273709
# Env x 0.7092419264846407 Env u -0.6328367097468928
# Obs : {'y': array([0.07640522], dtype=float32), 'p': array([0.22706626], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.48], dtype=float32)}
# Step: 12, Action: [0.22706626], Reward: -1.581055549744361
# Env x 1.4773370326285296 Env u -0.12381582387296387
# Obs : {'y': array([1.3535212], dtype=float32), 'p': array([-2.4725296], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.52], dtype=float32)}
# Step: 13, Action: [-2.4725296], Reward: -0.4259094836358269
# Env x 0.498147429239882 Env u 0.7709927409582115
# Obs : {'y': array([1.2691401], dtype=float32), 'p': array([1.3623583], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.56], dtype=float32)}
# Step: 14, Action: [1.3623583], Reward: -2.354399862671464
# Env x 0.9179814541926112 Env u 0.1785723512499877
# Obs : {'y': array([1.0965538], dtype=float32), 'p': array([0.15610024], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.6], dtype=float32)}
# Step: 15, Action: [0.15610024], Reward: -3.738532738375622
# Env x 0.4975990821019658 Env u -0.9689352871805795
# Obs : {'y': array([-0.47133622], dtype=float32), 'p': array([1.6467974], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.64], dtype=float32)}
# Step: 16, Action: [1.6467974], Reward: -1.5955118471385856
# Env x 0.03154289991856048 Env u 0.9412179419723656
# Obs : {'y': array([0.97276086], dtype=float32), 'p': array([3.0186424], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.68], dtype=float32)}
# Step: 17, Action: [3.0186424], Reward: 0.03920516043167389
# Env x 0.08810136119469791 Env u -1.4049099947509345
# Obs : {'y': array([-1.3168086], dtype=float32), 'p': array([2.8950362], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.72], dtype=float32)}
# Step: 18, Action: [2.8950362], Reward: -0.20115231528949645
# Env x -0.9242720700970779 Env u -1.9409961662014221
# Obs : {'y': array([-2.8652682], dtype=float32), 'p': array([5.], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.76], dtype=float32)}
# Step: 19, Action: [5.], Reward: -2.499538252733871
# Env x -0.01634635753712604 Env u -0.5603730838379214
# Obs : {'y': array([-0.57671946], dtype=float32), 'p': array([3.1305192], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.8], dtype=float32)}
# Step: 20, Action: [3.1305192], Reward: -0.08222737480802009
# Env x -0.7050064954206529 Env u 0.20712236100754985
# Obs : {'y': array([-0.49788412], dtype=float32), 'p': array([4.124871], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.84], dtype=float32)}
# Step: 21, Action: [4.124871], Reward: -0.5900125897576671
# Env x -1.6691995209951678 Env u 0.5952621613025373
# Obs : {'y': array([-1.0739374], dtype=float32), 'p': array([5.], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.88], dtype=float32)}
# Step: 22, Action: [5.], Reward: -0.9450731166866211
# Env x 7.361448466806028 Env u -0.1530046845540944
# Obs : {'y': array([7.2084436], dtype=float32), 'p': array([-2.8449183], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.92], dtype=float32)}
# Step: 23, Action: [-2.8449183], Reward: 6.386425391767735
# Env x 16.19298912785372 Env u -0.38955587294011823
# Obs : {'y': array([15.803433], dtype=float32), 'p': array([-4.157614], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.96], dtype=float32)}
# Step: 24, Action: [-4.157614], Reward: -52.32923380047462
# Env x 16.19298912785372 Env u -0.38955587294011823
# Obs : {'y': array([15.803433], dtype=float32), 'p': array([5.], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([1.], dtype=float32)}
# Step: 25, Action: [5.], Reward: 29.99774222204485

# %%
def evaluate_agent_actions_multiperiod_mm(model, env, action_scaling=5):
    obs, info = env.reset()

    steps = env.T
    optimal_insider_actions = np.zeros((steps))
    optimal_market_maker_actions = np.zeros((steps))

    trained_insider_actions = np.zeros((steps))
    trained_market_maker_actions = np.zeros((steps))

    values = np.linspace(1, steps, steps)

    p0 = env.p0
    v = env.v

    beta, lmbd = solve_kyle_model_mine(steps, env.sigma_v, env.sigma_u)

    total_reward_model = np.zeros((steps))
    total_reward_optimal = np.zeros((steps))

        

    for i in range(len(values)):
        
        trained_insider_actions[i] = equilibrium_insider_action(v, env.p, beta[i])
        optimal_insider_actions[i] = equilibrium_insider_action(v, p0, beta[i])
        u = env.u
        y = optimal_insider_actions[i] + u
        

        action, _ = model_mm.predict(obs, deterministic=True)
        trained_market_maker_actions[i] = action * action_scaling
        optimal_market_maker_actions[i] = equilibrium_market_maker_action(y, p0, lmbd[i])
        p0 = lmbd[i] * y + p0
        obs, reward, terminated, truncated, info = env_mm.step(action)

        

    env.reset()

    # plot: 2 subplots. one for insider (values vs action) and one for market maker (order vs action)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
    
    # Insider subplot
    ax1.plot(values, optimal_insider_actions, label="Optimal", linestyle='--')
    ax1.plot(values, trained_insider_actions, label="Trained", linestyle='-')
    ax1.axvline(x=env.p0, color='black', linestyle=':', alpha=0.5)
    ax1.axhline(y=0, color='black', linestyle=':', alpha=0.5)
    ax1.set_title("Insider Action")
    ax1.set_xlabel("Timestep t")
    ax1.set_ylabel("Action x")
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # Market Maker subplot
    ax2.plot(values, optimal_market_maker_actions, label="Optimal", linestyle='--')
    ax2.plot(values, trained_market_maker_actions, label="Trained", linestyle='-')
    ax2.axvline(x=0, color='black', linestyle=':', alpha=0.5)
    ax2.axhline(y=env.p0, color='black', linestyle=':', alpha=0.5)
    ax2.set_title("Market Maker Action")
    ax2.set_xlabel("Timestep t")
    ax2.set_ylabel("Price p")
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %%
evaluate_agent_actions_multiperiod_mm(model_mm, env_mm)
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_1844\3504994280.py:32: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   trained_market_maker_actions[i] = action * action_scaling
