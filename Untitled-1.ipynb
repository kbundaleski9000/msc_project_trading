# %%
import math
import gymnasium as gym
from gymnasium import spaces
from typing import Dict
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import A2C, SAC
from gym.wrappers import FlattenObservation
from typing import Tuple, Dict, Optional, Any
import matplotlib.pyplot as plt
from stable_baselines3.common.utils import get_linear_fn
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import SubprocVecEnv
import numpy as np
import random
from scipy.optimize import brentq
import torch
import torch.nn as nn
import torch.optim as optim
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
import numpy as np
from scipy.optimize import brentq
import matplotlib.pyplot as plt
import pandas as pd

def solve_kyle_model(N: int, sigma2_v: float, sigma2_u: float):
    """
    Calculates the multi-period Kyle model equilibrium using a two-pass algorithm.

    Args:
        N (int): The total number of trading periods.
        sigma2_v (float): The initial variance of the asset's value (Sigma_0).
        sigma2_u (float): The variance of the noise trader's orders.

    Returns:
        dict: A dictionary containing the numpy arrays for each equilibrium
              parameter sequence: 'Sigma', 'Lambda', 'Beta', and 'Alpha'.
    """
    # Helper for readability
    sigma_u = np.sqrt(sigma2_u)

    # --- ⏪ PASS 1: BACKWARD ITERATION for h_n ---
    # h_n = Sigma_n / Sigma_{n-1}
    h = np.zeros(N)
    h[-1] = 0.5  # Terminal condition for the last period (n=N)

    # Iterate backwards from n = N-1 down to n=1
    for n in reversed(range(N - 1)):
        # Calculate theta_{n+1} from the known h_{n+1}
        h_next = h[n + 1]
        theta_next = np.sqrt(h_next / (1 - h_next))

        # Define the function whose root h_n we need to find
        # f(h_n) = theta_{n+1} - (2*h_n - 1) / (h_n * sqrt(1-h_n)) = 0
        def root_func(h_n):
            if h_n <= 0.5 or h_n >= 1.0: # Numerical stability
                return np.inf
            return theta_next - (2 * h_n - 1) / (h_n * np.sqrt(1 - h_n))

        # Find the root h_n in the interval (0.5, 1.0)
        # brentq is a robust and efficient choice here.
        h[n] = brentq(root_func, 0.5 + 1e-9, 1.0 - 1e-9)

    # --- ⏩ PASS 2: FORWARD ITERATION for equilibrium parameters ---
    Sigma = np.zeros(N + 1)
    Lambda = np.zeros(N)
    Beta = np.zeros(N)
    Alpha = np.zeros(N)

    Sigma[0] = sigma2_v # Initial condition

    # Iterate forward from n=1 to N
    for n in range(N):
        # Update variance using the pre-calculated h_n
        Sigma[n + 1] = h[n] * Sigma[n]

        # Calculate the equilibrium parameters for period n
        Lambda[n] = np.sqrt((1 - h[n]) * Sigma[n + 1]) / sigma_u
        Beta[n] = (np.sqrt(1 - h[n]) * sigma_u) / np.sqrt(Sigma[n + 1])
        Alpha[n] = (sigma_u / (2 * np.sqrt(Sigma[n]))) * np.sqrt(h[n] / (1 - h[n]))
    
    return {
        "Sigma": Sigma,
        "Lambda": Lambda,
        "Beta": Beta,
        "Alpha": Alpha,
        "h": h
    }

if __name__ == '__main__':
    # --- Model Parameters ---
    N_periods = 20
    asset_value_variance = 1.0
    noise_trade_variance = 1.0

    # --- Solve the Model ---
    equilibrium = solve_kyle_model(N_periods, asset_value_variance, noise_trade_variance)

    # --- Display Results ---
    print("📈 Kyle Model Equilibrium Results")
    print(f"N = {N_periods}, Sigma_0 = {asset_value_variance}, sigma_u^2 = {noise_trade_variance}\n")

    # Create a pandas DataFrame for a clean table view
    periods = np.arange(1, N_periods + 1)
    df = pd.DataFrame({
        'Period': periods,
        'h_n': equilibrium['h'],
        'Sigma_n': equilibrium['Sigma'][1:],
        'Lambda_n': equilibrium['Lambda'],
        'Beta_n': equilibrium['Beta'],
        'Alpha_n': equilibrium['Alpha']
    })
    pd.set_option('display.precision', 4)
    print(df)

    # --- Plotting Key Dynamics ---
    fig, axs = plt.subplots(2, 2, figsize=(14, 10), constrained_layout=True)
    fig.suptitle(f'Kyle Model Equilibrium Dynamics (N={N_periods})', fontsize=16)

    # 1. Uncertainty (Sigma_n)
    axs[0, 0].plot(np.arange(N_periods + 1), equilibrium['Sigma'], 'o-', color='b')
    axs[0, 0].set_title('Market Maker Uncertainty ($\Sigma_n$)')
    axs[0, 0].set_xlabel('Period')
    axs[0, 0].set_ylabel('Variance')
    axs[0, 0].grid(True, linestyle='--', alpha=0.6)

    # 2. Price Impact (Lambda_n)
    axs[0, 1].plot(periods, equilibrium['Lambda'], 'o-', color='r')
    axs[0, 1].set_title('Price Impact ($\lambda_n$)')
    axs[0, 1].set_xlabel('Period')
    axs[0, 1].set_ylabel('Lambda')
    axs[0, 1].grid(True, linestyle='--', alpha=0.6)

    # 3. Trading Intensity (Beta_n)
    axs[1, 0].plot(periods, equilibrium['Beta'], 'o-', color='g')
    axs[1, 0].set_title('Insider Trading Intensity (β_n)')
    axs[1, 0].set_xlabel('Period')
    axs[1, 0].set_ylabel('Beta')
    axs[1, 0].grid(True, linestyle='--', alpha=0.6)

    # 4. Variance Reduction Rate (h_n)
    axs[1, 1].plot(periods, equilibrium['h'], 'o-', color='purple')
    axs[1, 1].set_title('Variance Reduction Rate ($h_n$)')
    axs[1, 1].set_xlabel('Period')
    axs[1, 1].set_ylabel('h_n')
    axs[1, 1].grid(True, linestyle='--', alpha=0.6)

    plt.show()
# Out:
# 📈 Kyle Model Equilibrium Results
# N = 20, Sigma_0 = 1.0, sigma_u^2 = 1.0
#
#     Period     h_n  Sigma_n  Lambda_n  Beta_n  Alpha_n
# 0        1  0.9562   0.9562    0.2046  0.2140   2.3363
# 1        2  0.9541   0.9123    0.2046  0.2243   2.3314
# 2        3  0.9518   0.8683    0.2046  0.2356   2.3260
# 3        4  0.9492   0.8242    0.2046  0.2482   2.3200
# 4        5  0.9464   0.7800    0.2045  0.2622   2.3134
# 5        6  0.9432   0.7357    0.2045  0.2780   2.3059
# 6        7  0.9395   0.6912    0.2045  0.2958   2.2976
# 7        8  0.9354   0.6465    0.2044  0.3162   2.2880
# 8        9  0.9306   0.6017    0.2043  0.3396   2.2771
# 9       10  0.9250   0.5566    0.2043  0.3670   2.2645
# 10      11  0.9185   0.5112    0.2041  0.3993   2.2496
# 11      12  0.9106   0.4655    0.2040  0.4382   2.2319
# 12      13  0.9010   0.4194    0.2038  0.4860   2.2104
# 13      14  0.8889   0.3728    0.2035  0.5460   2.1836
# 14      15  0.8733   0.3255    0.2031  0.6240   2.1495
# 15      16  0.8522   0.2774    0.2025  0.7299   2.1042
# 16      17  0.8221   0.2281    0.2014  0.8831   2.0409
# 17      18  0.7754   0.1769    0.1993  1.1269   1.9454
# 18      19  0.6920   0.1224    0.1941  1.5863   1.7822
# 19      20  0.5000   0.0612    0.1749  2.8585   1.4292

# %%
def solve_kyle_model_mine(N: int, sigma2_v: float, sigma2_u: float):
    """
    Calculates the multi-period Kyle model equilibrium using a two-pass algorithm.

    Args:
        N (int): The total number of trading periods.
        sigma2_v (float): The initial variance of the asset's value (Sigma_0).
        sigma2_u (float): The variance of the noise trader's orders.

    Returns:
        dict: A dictionary containing the numpy arrays for each equilibrium
              parameter sequence: 'Sigma', 'Lambda', 'Beta', and 'Alpha'.
    """
    # Helper for readability
    sigma_u = np.sqrt(sigma2_u)

    # --- ⏪ PASS 1: BACKWARD ITERATION for h_n ---
    # h_n = Sigma_n / Sigma_{n-1}
    h = np.zeros(N)
    h[-1] = 0.5  # Terminal condition for the last period (n=N)

    # Iterate backwards from n = N-1 down to n=1
    for n in reversed(range(N - 1)):
        # Calculate theta_{n+1} from the known h_{n+1}
        h_next = h[n + 1]
        theta_next = np.sqrt(h_next / (1 - h_next))

        # Define the function whose root h_n we need to find
        # f(h_n) = theta_{n+1} - (2*h_n - 1) / (h_n * sqrt(1-h_n)) = 0
        def root_func(h_n):
            if h_n <= 0.5 or h_n >= 1.0: # Numerical stability
                return np.inf
            return theta_next - (2 * h_n - 1) / (h_n * np.sqrt(1 - h_n))

        # Find the root h_n in the interval (0.5, 1.0)
        # brentq is a robust and efficient choice here.
        h[n] = brentq(root_func, 0.5 + 1e-9, 1.0 - 1e-9)

    # --- ⏩ PASS 2: FORWARD ITERATION for equilibrium parameters ---
    Sigma = np.zeros(N + 1)
    Lambda = np.zeros(N)
    Beta = np.zeros(N)
    Alpha = np.zeros(N)

    Sigma[0] = sigma2_v # Initial condition

    # Iterate forward from n=1 to N
    for n in range(N):
        # Update variance using the pre-calculated h_n
        Sigma[n + 1] = h[n] * Sigma[n]

        # Calculate the equilibrium parameters for period n
        Lambda[n] = np.sqrt((1 - h[n]) * Sigma[n + 1]) / sigma_u
        Beta[n] = (np.sqrt(1 - h[n]) * sigma_u) / np.sqrt(Sigma[n + 1])
        Alpha[n] = (sigma_u / (2 * np.sqrt(Sigma[n]))) * np.sqrt(h[n] / (1 - h[n]))
    
    return Beta, Lambda

# %%
def equilibrium_insider_action(v, mean_v, beta):
    return beta * (v - mean_v)

def equilibrium_market_maker_action(y, mean_v, lambda_):
    return mean_v + lambda_ * y

# %%
class KyleModelEnv(gym.Env):
    metadata = {'render_modes': ['human']}

    def __init__(self, sigma_v=2.0, sigma_u=1.0, p0=0.5, T=25, gamma=0.95, action_scaling = 5):
        super(KyleModelEnv, self).__init__()
        
        self.action_scaling = action_scaling
        self.sigma_v = sigma_v
        self.sigma_u = sigma_u
        self.p0 = p0
        self.T = T
        self.u = 0.0
        self.gamma = gamma
        self.actual_actions = []
        self.beta = np.zeros(self.T)
        self.lmbd = np.zeros(self.T)
        self.alpha = np.zeros(self.T)
        self.h = np.zeros(self.T)
        self.Sigma = np.zeros(self.T)
        self.delta = np.zeros(self.T)
        self.solve_kyle_model()

        # Define action and observation spaces
        self.action_space = spaces.Box(
            low=-1.0,
            high=1.0,
            shape=(1,),
            dtype=np.float32
        )

        self.observation_space = spaces.Dict({
            'v': spaces.Box(low=-np.inf, high=np.inf, shape=(1,), dtype=np.float32),
            'p': spaces.Box(low=-np.inf, high=np.inf, shape=(1,), dtype=np.float32),
            'sigma_v': spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32),
            'sigma_u': spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32),
            'time': spaces.Box(low=0, high=self.T, shape=(1,), dtype=np.float32)
        })

        self.reset()

    def reset(self, seed=None, options=None):
        """Reset environment to initial state"""
        super().reset(seed=seed)

        self.v = np.random.normal(self.p0, self.sigma_v)  # True asset value
        self.p = self.p0
        self.t = 0
        self.sigma_v = 2.0
        self.solve_kyle_model()

        obs = self._get_insider_obs()
        info = {}
        return obs, info  # Gymnasium requires (obs, info)

    def _get_insider_obs(self):
        return {
            'v': np.array([self.v], dtype=np.float32),
            'p': np.array([self.p], dtype=np.float32),
            'sigma_v': np.array([self.sigma_v], dtype=np.float32),
            'sigma_u': np.array([self.sigma_u], dtype=np.float32),
            'time': np.array([self.t/self.T], dtype=np.float32)
        }
    
    def solve_kyle_model(self):
        """
        Calculates the multi-period Kyle model equilibrium using a two-pass algorithm.

        Args:
            N (int): The total number of trading periods.
            sigma2_v (float): The initial variance of the asset's value (Sigma_0).
            sigma2_u (float): The variance of the noise trader's orders.

        Returns:
            dict: A dictionary containing the numpy arrays for each equilibrium
                parameter sequence: 'Sigma', 'Lambda', 'Beta', and 'Alpha'.
        """
        # Helper for readability
        sigma_u = np.sqrt(self.sigma_u)

        # --- ⏪ PASS 1: BACKWARD ITERATION for h_n ---
        # h_n = Sigma_n / Sigma_{n-1}
        h = np.zeros(self.T)
        h[-1] = 0.5  # Terminal condition for the last period (n=N)

        # Iterate backwards from n = N-1 down to n=1
        for n in reversed(range(self.T - 1)):
            # Calculate theta_{n+1} from the known h_{n+1}
            h_next = h[n + 1]
            theta_next = np.sqrt(h_next / (1 - h_next))

            # Define the function whose root h_n we need to find
            # f(h_n) = theta_{n+1} - (2*h_n - 1) / (h_n * sqrt(1-h_n)) = 0
            def root_func(h_n):
                if h_n <= 0.5 or h_n >= 1.0: # Numerical stability
                    return np.inf
                return theta_next - (2 * h_n - 1) / (h_n * np.sqrt(1 - h_n))

            # Find the root h_n in the interval (0.5, 1.0)
            # brentq is a robust and efficient choice here.
            h[n] = brentq(root_func, 0.5 + 1e-9, 1.0 - 1e-9)

        # --- ⏩ PASS 2: FORWARD ITERATION for equilibrium parameters ---
        Sigma = np.zeros(self.T + 1)
        Lambda = np.zeros(self.T)
        Beta = np.zeros(self.T)
        Alpha = np.zeros(self.T)

        Sigma[0] = self.sigma_v # Initial condition

        # Iterate forward from n=1 to N
        for n in range(self.T):
            # Update variance using the pre-calculated h_n
            Sigma[n + 1] = h[n] * Sigma[n]

            # Calculate the equilibrium parameters for period n
            Lambda[n] = np.sqrt((1 - h[n]) * Sigma[n + 1]) / sigma_u
            Beta[n] = (np.sqrt(1 - h[n]) * sigma_u) / np.sqrt(Sigma[n + 1])
            Alpha[n] = (sigma_u / (2 * np.sqrt(Sigma[n]))) * np.sqrt(h[n] / (1 - h[n]))
        
        self.beta = Beta
        self.lmbd = Lambda
        self.alpha = Alpha
        self.h = h
        self.Sigma = Sigma

        self.delta[self.T-1] = 0  # Terminal condition
        
        for n in reversed(range(1, self.T-1)):
            self.delta[n-1] = self.delta[n] + self.alpha[n] * ( self.lmbd[n] ** 2 ) * self.sigma_u

    def step(self, action):
        """Execute one step"""
        if self.t >= self.T:
            raise ValueError("Episode has already ended")

        scaled_action = action * self.action_scaling
        self.actual_actions.append(scaled_action[0])

        x = scaled_action[0]
        self.u = np.random.normal(0, self.sigma_u)
        y = x + self.u
        p_new = self.p + self.lmbd[self.t] * y


        insider_profit = (self.v - p_new) * x

        # Update state
        self.p = p_new
        self.t += 1
        self.sigma_v = self.Sigma[self.t]
            

        terminated = (self.t >= self.T)  # natural end
        truncated = False  # No time/truncation logic here

        obs = self._get_insider_obs()
        info = {}

        return obs, insider_profit, terminated, truncated, info



# Example usage with Gym interface
print("Testing Kyle model with Gym interface")

env_insider = KyleModelEnv()

# Initialize the model

clip_range_schedule = get_linear_fn(start=0.4, end=0.2, end_fraction=0.8)

policy_kwargs = dict(
    net_arch=dict(pi=[128,128], vf=[128,128])  # Separate networks
)

model_insider = PPO(
    "MultiInputPolicy",
    env_insider,
    verbose = 1,
    learning_rate = 0.0004,
    clip_range = clip_range_schedule,
    policy_kwargs=policy_kwargs

)
# Out:
# Testing Kyle model with Gym interface
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
action_scaling = 5
plots_number = 1

# %%
model_insider.learn(total_timesteps=50_000)

# Test trained agent
obs = env_insider.reset()
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 2.1      |
# | time/              |          |
# |    fps             | 2441     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25         |
# |    ep_rew_mean          | 2.21       |
# | time/                   |            |
# |    fps                  | 1688       |
# |    iterations           | 2          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01975328 |
# |    clip_fraction        | 0.0325     |
# |    clip_range           | 0.39       |
# |    entropy_loss         | 1.05       |
# |    explained_variance   | 0.405      |
# |    learning_rate        | 0.0004     |
# |    loss                 | 0.727      |
# |    n_updates            | 324        |
# |    policy_gradient_loss | -0.00129   |
# |    std                  | 0.0841     |
# |    value_loss           | 2          |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.16        |
# | time/                   |             |
# |    fps                  | 1558        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016577471 |
# |    clip_fraction        | 0.0284      |
# |    clip_range           | 0.38        |
# |    entropy_loss         | 1.07        |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.51        |
# |    n_updates            | 334         |
# |    policy_gradient_loss | -0.00184    |
# |    std                  | 0.0825      |
# |    value_loss           | 1.5         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 1.96        |
# | time/                   |             |
# |    fps                  | 1507        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015940731 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.369       |
# |    entropy_loss         | 1.09        |
# |    explained_variance   | 0.383       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 1.09        |
# |    n_updates            | 344         |
# |    policy_gradient_loss | -0.00848    |
# |    std                  | 0.0812      |
# |    value_loss           | 1.55        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.43        |
# | time/                   |             |
# |    fps                  | 1475        |
# |    iterations           | 5           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018945012 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.359       |
# |    entropy_loss         | 1.12        |
# |    explained_variance   | 0.272       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.384       |
# |    n_updates            | 354         |
# |    policy_gradient_loss | -0.0027     |
# |    std                  | 0.0777      |
# |    value_loss           | 1.09        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.53        |
# | time/                   |             |
# |    fps                  | 1455        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008691106 |
# |    clip_fraction        | 0.0299      |
# |    clip_range           | 0.349       |
# |    entropy_loss         | 1.14        |
# |    explained_variance   | 0.317       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 1.05        |
# |    n_updates            | 364         |
# |    policy_gradient_loss | -0.00153    |
# |    std                  | 0.0764      |
# |    value_loss           | 1.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.81        |
# | time/                   |             |
# |    fps                  | 1441        |
# |    iterations           | 7           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.017301302 |
# |    clip_fraction        | 0.051       |
# |    clip_range           | 0.339       |
# |    entropy_loss         | 1.19        |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.58        |
# |    n_updates            | 374         |
# |    policy_gradient_loss | -0.0049     |
# |    std                  | 0.0718      |
# |    value_loss           | 1.4         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.25        |
# | time/                   |             |
# |    fps                  | 1429        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011524126 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.328       |
# |    entropy_loss         | 1.23        |
# |    explained_variance   | 0.386       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.673       |
# |    n_updates            | 384         |
# |    policy_gradient_loss | -0.00143    |
# |    std                  | 0.0699      |
# |    value_loss           | 1.93        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 1.76        |
# | time/                   |             |
# |    fps                  | 1420        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.010129503 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.318       |
# |    entropy_loss         | 1.26        |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.73        |
# |    n_updates            | 394         |
# |    policy_gradient_loss | 0.000692    |
# |    std                  | 0.0683      |
# |    value_loss           | 1.33        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.49        |
# | time/                   |             |
# |    fps                  | 1414        |
# |    iterations           | 10          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008615165 |
# |    clip_fraction        | 0.048       |
# |    clip_range           | 0.308       |
# |    entropy_loss         | 1.29        |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.181       |
# |    n_updates            | 404         |
# |    policy_gradient_loss | 0.00144     |
# |    std                  | 0.0656      |
# |    value_loss           | 1.03        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.23        |
# | time/                   |             |
# |    fps                  | 1409        |
# |    iterations           | 11          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.011785499 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.298       |
# |    entropy_loss         | 1.31        |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 1.49        |
# |    n_updates            | 414         |
# |    policy_gradient_loss | -0.000818   |
# |    std                  | 0.0648      |
# |    value_loss           | 1.89        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.68        |
# | time/                   |             |
# |    fps                  | 1405        |
# |    iterations           | 12          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013810925 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.287       |
# |    entropy_loss         | 1.32        |
# |    explained_variance   | 0.251       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.484       |
# |    n_updates            | 424         |
# |    policy_gradient_loss | -0.00182    |
# |    std                  | 0.0643      |
# |    value_loss           | 1.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.05        |
# | time/                   |             |
# |    fps                  | 1403        |
# |    iterations           | 13          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005923927 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.277       |
# |    entropy_loss         | 1.33        |
# |    explained_variance   | 0.403       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 1.02        |
# |    n_updates            | 434         |
# |    policy_gradient_loss | -2.23e-05   |
# |    std                  | 0.0635      |
# |    value_loss           | 2.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.06        |
# | time/                   |             |
# |    fps                  | 1400        |
# |    iterations           | 14          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006938358 |
# |    clip_fraction        | 0.0465      |
# |    clip_range           | 0.267       |
# |    entropy_loss         | 1.34        |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.398       |
# |    n_updates            | 444         |
# |    policy_gradient_loss | 0.00237     |
# |    std                  | 0.0629      |
# |    value_loss           | 1.08        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.44        |
# | time/                   |             |
# |    fps                  | 1398        |
# |    iterations           | 15          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007951394 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.257       |
# |    entropy_loss         | 1.36        |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.47        |
# |    n_updates            | 454         |
# |    policy_gradient_loss | -0.00123    |
# |    std                  | 0.0608      |
# |    value_loss           | 0.949       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25           |
# |    ep_rew_mean          | 2.27         |
# | time/                   |              |
# |    fps                  | 1397         |
# |    iterations           | 16           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0068018096 |
# |    clip_fraction        | 0.0564       |
# |    clip_range           | 0.246        |
# |    entropy_loss         | 1.4          |
# |    explained_variance   | 0.391        |
# |    learning_rate        | 0.0004       |
# |    loss                 | 1.29         |
# |    n_updates            | 464          |
# |    policy_gradient_loss | -0.000842    |
# |    std                  | 0.0592       |
# |    value_loss           | 1.84         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25           |
# |    ep_rew_mean          | 2.31         |
# | time/                   |              |
# |    fps                  | 1395         |
# |    iterations           | 17           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0070202597 |
# |    clip_fraction        | 0.0684       |
# |    clip_range           | 0.236        |
# |    entropy_loss         | 1.42         |
# |    explained_variance   | 0.3          |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.586        |
# |    n_updates            | 474          |
# |    policy_gradient_loss | -5.2e-05     |
# |    std                  | 0.0585       |
# |    value_loss           | 1.25         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25           |
# |    ep_rew_mean          | 2.42         |
# | time/                   |              |
# |    fps                  | 1394         |
# |    iterations           | 18           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0069232015 |
# |    clip_fraction        | 0.0602       |
# |    clip_range           | 0.226        |
# |    entropy_loss         | 1.42         |
# |    explained_variance   | 0.447        |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.481        |
# |    n_updates            | 484          |
# |    policy_gradient_loss | 0.000732     |
# |    std                  | 0.0583       |
# |    value_loss           | 1.38         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.5         |
# | time/                   |             |
# |    fps                  | 1394        |
# |    iterations           | 19          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009210769 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.216       |
# |    entropy_loss         | 1.43        |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.498       |
# |    n_updates            | 494         |
# |    policy_gradient_loss | -0.00109    |
# |    std                  | 0.0572      |
# |    value_loss           | 1.4         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25         |
# |    ep_rew_mean          | 2.69       |
# | time/                   |            |
# |    fps                  | 1390       |
# |    iterations           | 20         |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.00528148 |
# |    clip_fraction        | 0.0788     |
# |    clip_range           | 0.205      |
# |    entropy_loss         | 1.45       |
# |    explained_variance   | 0.267      |
# |    learning_rate        | 0.0004     |
# |    loss                 | 0.557      |
# |    n_updates            | 504        |
# |    policy_gradient_loss | 9.75e-05   |
# |    std                  | 0.0561     |
# |    value_loss           | 1.43       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25           |
# |    ep_rew_mean          | 2.29         |
# | time/                   |              |
# |    fps                  | 1387         |
# |    iterations           | 21           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0055701407 |
# |    clip_fraction        | 0.0774       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.46         |
# |    explained_variance   | 0.419        |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.935        |
# |    n_updates            | 514          |
# |    policy_gradient_loss | 0.00183      |
# |    std                  | 0.056        |
# |    value_loss           | 2.13         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25           |
# |    ep_rew_mean          | 2.16         |
# | time/                   |              |
# |    fps                  | 1386         |
# |    iterations           | 22           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0043654507 |
# |    clip_fraction        | 0.0977       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.46         |
# |    explained_variance   | 0.323        |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.454        |
# |    n_updates            | 524          |
# |    policy_gradient_loss | -0.000335    |
# |    std                  | 0.0561       |
# |    value_loss           | 1.12         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.28        |
# | time/                   |             |
# |    fps                  | 1385        |
# |    iterations           | 23          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009724686 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 1.48        |
# |    explained_variance   | 0.4         |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.238       |
# |    n_updates            | 534         |
# |    policy_gradient_loss | -0.000473   |
# |    std                  | 0.0546      |
# |    value_loss           | 1.47        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25           |
# |    ep_rew_mean          | 2.52         |
# | time/                   |              |
# |    fps                  | 1384         |
# |    iterations           | 24           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0099929385 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 1.51         |
# |    explained_variance   | 0.338        |
# |    learning_rate        | 0.0004       |
# |    loss                 | 1.37         |
# |    n_updates            | 544          |
# |    policy_gradient_loss | 0.000444     |
# |    std                  | 0.0528       |
# |    value_loss           | 1.68         |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 model_insider.learn(total_timesteps=50_000)
#       3 # Test trained agent
#       4 obs = env_insider.reset()
#
# File c:\Uzh\thesis\thesisenv311\Lib\site-packages\stable_baselines3\ppo\ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)    309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File c:\Uzh\thesis\thesisenv311\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:337, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     334         assert self.ep_info_buffer is not None
#     335         self.dump_logs(iteration)
# --> 337     self.train()
#     339 callback.on_training_end()
#     341 return self
#
# File c:\Uzh\thesis\thesisenv311\Lib\site-packages\stable_baselines3\ppo\ppo.py:213, in PPO.train(self)
#     209 if isinstance(self.action_space, spaces.Discrete):
#     210     # Convert discrete action from float to long
#     211     actions = rollout_data.actions.long().flatten()
# --> 213 values, log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#     214 values = values.flatten()
#     215 # Normalize advantage
#
# File c:\Uzh\thesis\thesisenv311\Lib\site-packages\stable_baselines3\common\policies.py:737, in ActorCriticPolicy.evaluate_actions(self, obs, actions)
#     735     latent_pi = self.mlp_extractor.forward_actor(pi_features)
#     736     latent_vf = self.mlp_extractor.forward_critic(vf_features)
# --> 737 distribution = self._get_action_dist_from_latent(latent_pi)
#     738 log_prob = distribution.log_prob(actions)
#     739 values = self.value_net(latent_vf)
#
# File c:\Uzh\thesis\thesisenv311\Lib\site-packages\stable_baselines3\common\policies.py:694, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     691 mean_actions = self.action_net(latent_pi)
#     693 if isinstance(self.action_dist, DiagGaussianDistribution):
# --> 694     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     695 elif isinstance(self.action_dist, CategoricalDistribution):
#     696     # Here mean_actions are the logits before the softmax
#     697     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File c:\Uzh\thesis\thesisenv311\Lib\site-packages\stable_baselines3\common\distributions.py:164, in DiagGaussianDistribution.proba_distribution(self, mean_actions, log_std)
#     156 """
#     157 Create the distribution given its parameters (mean, std)
#     158
#    (...)    161 :return:
#     162 """
#     163 action_std = th.ones_like(mean_actions) * log_std.exp()
# --> 164 self.distribution = Normal(mean_actions, action_std)
#     165 return self
#
# File c:\Uzh\thesis\thesisenv311\Lib\site-packages\torch\distributions\normal.py:66, in Normal.__init__(self, loc, scale, validate_args)
#      64 else:
#      65     batch_shape = self.loc.size()
# ---> 66 super().__init__(batch_shape, validate_args=validate_args)
#
# File c:\Uzh\thesis\thesisenv311\Lib\site-packages\torch\distributions\distribution.py:76, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      74         value = getattr(self, param)
#      75         valid = constraint.check(value)
# ---> 76         if not torch._is_all_true(valid):
#      77             raise ValueError(
#      78                 f"Expected parameter {param} "
#      79                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)     82                 f"but found invalid values:\n{value}"
#      83             )
#      84 super().__init__()
#
# KeyboardInterrupt:

# %%
obs, info = env_insider.reset()
done = False



while not done:
    action, _ = model_insider.predict(obs, deterministic=True) 

    obs_tensor = model_insider.policy.obs_to_tensor(obs)[0]
    dist = model_insider.policy.get_distribution(obs_tensor)

    action_mean = dist.distribution.mean.detach().cpu().numpy().flatten()
    action_std  = dist.distribution.stddev.detach().cpu().numpy().flatten()
    action *= action_scaling
    obs, reward, terminated, truncated, info = env_insider.step(action)
    done = terminated or truncated

    print(f"Action distribution after training: mean={action_mean*5}, std={action_std}")

    print(f"Step: {env_insider.t}, Action: {action}, Reward: {reward} , env u : {env_insider.u}")
# Out:
# Action distribution after training: mean=[0.4862073], std=[0.0524672]
# Step: 1, Action: [0.4862073], Reward: 0.4003001705944363 , env u : 0.3640714860393633
# Action distribution after training: mean=[0.18804514], std=[0.0524672]
# Step: 2, Action: [0.18804514], Reward: 0.41301830316951316 , env u : -1.98710430131425
# Action distribution after training: mean=[0.30990222], std=[0.0524672]
# Step: 3, Action: [0.30990222], Reward: -0.3164716650849514 , env u : 0.903832606285786
# Action distribution after training: mean=[0.05941739], std=[0.0524672]
# Step: 4, Action: [0.05941739], Reward: 0.023357617767298316 , env u : -1.375541403026354
# Action distribution after training: mean=[0.15911344], std=[0.0524672]
# Step: 5, Action: [0.15911344], Reward: -0.022772824020021083 , env u : -0.38664222097591494
# Action distribution after training: mean=[0.11867169], std=[0.0524672]
# Step: 6, Action: [0.11867169], Reward: -0.29820255336604623 , env u : 1.2139049795175596
# Action distribution after training: mean=[-0.02053281], std=[0.0524672]
# Step: 7, Action: [-0.02053281], Reward: 0.04563070543172645 , env u : -0.11891138005453439
# Action distribution after training: mean=[-0.00999509], std=[0.0524672]
# Step: 8, Action: [-0.00999509], Reward: 0.04798940169411176 , env u : 2.0172347383631695
# Action distribution after training: mean=[-0.10359304], std=[0.0524672]
# Step: 9, Action: [-0.10359304], Reward: 0.44978498074696527 , env u : 0.16744486676369336
# Action distribution after training: mean=[-0.09840216], std=[0.0524672]
# Step: 10, Action: [-0.09840216], Reward: 0.37469355935160376 , env u : 0.08450325616729291
# Action distribution after training: mean=[-0.08906574], std=[0.0524672]
# Step: 11, Action: [-0.08906574], Reward: 0.3828271479689818 , env u : 0.8196429972823481
# Action distribution after training: mean=[-0.1156778], std=[0.0524672]
# Step: 12, Action: [-0.1156778], Reward: 0.5639793557445223 , env u : 1.0189683837892283
# Action distribution after training: mean=[-0.14975968], std=[0.0524672]
# Step: 13, Action: [-0.14975968], Reward: 0.7863363804849131 , env u : 1.0352946902022797
# Action distribution after training: mean=[-0.1849284], std=[0.0524672]
# Step: 14, Action: [-0.1849284], Reward: 0.5613060454428812 , env u : -0.7674537787242662
# Action distribution after training: mean=[-0.10519297], std=[0.0524672]
# Step: 15, Action: [-0.10519297], Reward: 0.40976766198186915 , env u : 1.1831966854825904
# Action distribution after training: mean=[-0.1791595], std=[0.0524672]
# Step: 16, Action: [-0.1791595], Reward: 0.7842625655449071 , env u : 1.2643441764217893
# Action distribution after training: mean=[-0.2497699], std=[0.0524672]
# Step: 17, Action: [-0.2497699], Reward: 0.9035187645963871 , env u : 0.6673682753270187
# Action distribution after training: mean=[-0.24676739], std=[0.0524672]
# Step: 18, Action: [-0.24676739], Reward: 0.8850430754749048 , env u : 1.2102074531197078
# Action distribution after training: mean=[-0.30753794], std=[0.0524672]
# Step: 19, Action: [-0.30753794], Reward: -0.215784347196814 , env u : -1.7505765924538965
# Action distribution after training: mean=[0.17456737], std=[0.0524672]
# Step: 20, Action: [0.17456737], Reward: -0.3538183209354855 , env u : 1.2235626739116852
# Action distribution after training: mean=[-0.28471595], std=[0.0524672]
# Step: 21, Action: [-0.28471595], Reward: -0.25076958320444465 , env u : -0.817422726209809
# Action distribution after training: mean=[0.18693897], std=[0.0524672]
# Step: 22, Action: [0.18693897], Reward: 0.09709036603711994 , env u : -0.6546498404185005
# Action distribution after training: mean=[0.07101483], std=[0.0524672]
# Step: 23, Action: [0.07101483], Reward: -0.0529172915277567 , env u : 0.6351992120491367
# Action distribution after training: mean=[-0.32932666], std=[0.0524672]
# Step: 24, Action: [-0.32932666], Reward: -1.3760501180936995 , env u : -2.311321067394694
# Action distribution after training: mean=[1.0302459], std=[0.0524672]
# Step: 25, Action: [1.0302459], Reward: -2.0713367105666727 , env u : 0.37078709886282823

# %%
def evaluate_agent_actions_multiperiod(model, env, n_stdevs, action_scaling=5):
    obs, info = env.reset()

    steps = env.T
    optimal_insider_actions = np.zeros((steps))
    optimal_market_maker_actions = np.zeros((steps))

    trained_insider_actions = np.zeros((steps))
    trained_market_maker_actions = np.zeros((steps))

    values = np.linspace(1, steps, steps)
    beta, lmbd = solve_kyle_model_mine(steps, env.sigma_v, env.sigma_u)

    p0 = env.p0
    v = env.v

    total_reward_model = np.zeros((steps))
    total_reward_optimal = np.zeros((steps))

        

    for i in range(len(values)):
        
        action, _ = model_insider.predict(obs, deterministic=True) 
        obs, reward, terminated, truncated, info = env_insider.step(action)
        trained_insider_actions[i] = action * action_scaling 
        optimal_insider_actions[i] = equilibrium_insider_action(v, p0, beta[i])
        u = env.u
        y = optimal_insider_actions[i] + u
        total_reward_model[i] = reward
        

        trained_market_maker_actions[i] = env.p
        optimal_market_maker_actions[i] = equilibrium_market_maker_action(y, p0, lmbd[i])
        p0 = lmbd[i] * y + p0
        total_reward_optimal[i] = (v - optimal_market_maker_actions[i]) * optimal_insider_actions[i]

        

    env.reset()

    # plot: 2 subplots. one for insider (values vs action) and one for market maker (order vs action)
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 5))
    
    # Insider subplot
    ax1.plot(values, optimal_insider_actions, label="Optimal", linestyle='--')
    ax1.plot(values, trained_insider_actions, label="Trained", linestyle='-')
    ax1.axvline(x=env.p0, color='black', linestyle=':', alpha=0.5)
    ax1.axhline(y=0, color='black', linestyle=':', alpha=0.5)
    ax1.set_title("Insider Action")
    ax1.set_xlabel("Timestep t")
    ax1.set_ylabel("Action x")
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # Market Maker subplot
    ax2.plot(values, optimal_market_maker_actions, label="Optimal", linestyle='--')
    ax2.plot(values, trained_market_maker_actions, label="Trained", linestyle='-')
    ax2.axvline(x=0, color='black', linestyle=':', alpha=0.5)
    ax2.axhline(y=env.p0, color='black', linestyle=':', alpha=0.5)
    ax2.set_title("Market Maker Action")
    ax2.set_xlabel("Timestep t")
    ax2.set_ylabel("Price p")
    ax2.legend()
    ax2.grid(True, alpha=0.3)

        # Insider Reward subplot
    ax3.plot(values, total_reward_optimal, label="Optimal", linestyle='--')
    ax3.plot(values, total_reward_model, label="Trained", linestyle='-')
    ax3.axvline(x=env.p0, color='black', linestyle=':', alpha=0.5)
    ax3.axhline(y=0, color='black', linestyle=':', alpha=0.5)
    ax3.set_title("Insider Action")
    ax3.set_xlabel("Timestep t")
    ax3.set_ylabel("Action x")
    ax3.legend()
    ax3.grid(True, alpha=0.3)
    
    
    plt.tight_layout()
    plt.show() 

    return total_reward_model, total_reward_optimal

# %%
for _ in range(plots_number):
    trm, tro = evaluate_agent_actions_multiperiod(model_insider, env_insider, n_stdevs=3, action_scaling=action_scaling)
# Out:
# C:\Users\krist\AppData\Local\Temp\ipykernel_31984\1112799624.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   trained_insider_actions[i] = action * action_scaling

# %%
from stable_baselines3 import SAC

# %%
class KyleModelEnvMM(gym.Env):
    metadata = {'render_modes': ['human']}

    def __init__(self, sigma_v=2.0, sigma_u=1.0, p0=0.5, T=25, gamma=0.9, action_scaling = 5):
        super(KyleModelEnvMM, self).__init__()

        self.action_scaling = action_scaling
        self.sigma_v = sigma_v
        self.sigma_u = sigma_u
        self.p0 = p0
        self.T = T
        self.gamma = gamma
        self.actual_actions = []
        self.beta = np.zeros(self.T)
        self.lmbd = np.zeros(self.T)
        self.alpha = np.zeros(self.T)
        self.h = np.zeros(self.T)
        self.Sigma = np.zeros(self.T)
        self.delta = np.zeros(self.T)
        self.solve_kyle_model()

        # Define action space (Market Maker's price guess)
        self.action_space = spaces.Box(
            low=-1.0,
            high=1.0,
            shape=(1,),
            dtype=np.float32
        )

        # Observation space for the market maker
        self.observation_space = spaces.Dict({
            'y': spaces.Box(low=-np.inf, high=np.inf, shape=(1,), dtype=np.float32),
            'p': spaces.Box(low=-np.inf, high=np.inf, shape=(1,), dtype=np.float32),
            'sigma_v': spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32),
            'sigma_u': spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32),
            'time': spaces.Box(low=0, high=self.T, shape=(1,), dtype=np.float32)
        })

    def solve_kyle_model(self):
        """
        Calculates the multi-period Kyle model equilibrium using a two-pass algorithm.

        Args:
            N (int): The total number of trading periods.
            sigma2_v (float): The initial variance of the asset's value (Sigma_0).
            sigma2_u (float): The variance of the noise trader's orders.

        Returns:
            dict: A dictionary containing the numpy arrays for each equilibrium
                parameter sequence: 'Sigma', 'Lambda', 'Beta', and 'Alpha'.
        """
        # Helper for readability
        sigma_u = np.sqrt(self.sigma_u)

        # --- ⏪ PASS 1: BACKWARD ITERATION for h_n ---
        # h_n = Sigma_n / Sigma_{n-1}
        h = np.zeros(self.T)
        h[-1] = 0.5  # Terminal condition for the last period (n=N)

        # Iterate backwards from n = N-1 down to n=1
        for n in reversed(range(self.T - 1)):
            # Calculate theta_{n+1} from the known h_{n+1}
            h_next = h[n + 1]
            theta_next = np.sqrt(h_next / (1 - h_next))

            # Define the function whose root h_n we need to find
            # f(h_n) = theta_{n+1} - (2*h_n - 1) / (h_n * sqrt(1-h_n)) = 0
            def root_func(h_n):
                if h_n <= 0.5 or h_n >= 1.0: # Numerical stability
                    return np.inf
                return theta_next - (2 * h_n - 1) / (h_n * np.sqrt(1 - h_n))

            # Find the root h_n in the interval (0.5, 1.0)
            # brentq is a robust and efficient choice here.
            h[n] = brentq(root_func, 0.5 + 1e-9, 1.0 - 1e-9)

        # --- ⏩ PASS 2: FORWARD ITERATION for equilibrium parameters ---
        Sigma = np.zeros(self.T + 1)
        Lambda = np.zeros(self.T)
        Beta = np.zeros(self.T)
        Alpha = np.zeros(self.T)

        Sigma[0] = self.sigma_v # Initial condition

        # Iterate forward from n=1 to N
        for n in range(self.T):
            # Update variance using the pre-calculated h_n
            Sigma[n + 1] = h[n] * Sigma[n]

            # Calculate the equilibrium parameters for period n
            Lambda[n] = np.sqrt((1 - h[n]) * Sigma[n + 1]) / sigma_u
            Beta[n] = (np.sqrt(1 - h[n]) * sigma_u) / np.sqrt(Sigma[n + 1])
            Alpha[n] = (sigma_u / (2 * np.sqrt(Sigma[n]))) * np.sqrt(h[n] / (1 - h[n]))
        
        self.beta = Beta
        self.lmbd = Lambda
        self.alpha = Alpha
        self.h = h
        self.Sigma = Sigma

        self.delta[self.T-1] = 0  # Terminal condition
        
        for n in reversed(range(1, self.T-1)):
            self.delta[n-1] = self.delta[n] + self.alpha[n] * ( self.lmbd[n] ** 2 ) * self.sigma_u

    def reset(self, *, seed=None, options=None):
        """Reset the environment to initial state"""
        super().reset(seed=seed)

        # True asset value is drawn from N(p0, sigma_v^2)
        self.v = np.random.normal(self.p0, self.sigma_v)

        # Initialize state variables
        self.p = self.p0
        self.t = 0

        # Generate initial observation
        self.x = self.beta[self.t] * (self.v - self.p)
        self.u = np.random.normal(0, self.sigma_u)
        self.y = self.x + self.u

        obs = self._get_mm_obs()
        info = {}
        return obs, info  # Gymnasium requires (obs, info)

    def _get_mm_obs(self) -> Dict[str, np.ndarray]:
        return {
            'y': np.array([self.y], dtype=np.float32),
            'p': np.array([self.p], dtype=np.float32),
            'sigma_v': np.array([self.sigma_v], dtype=np.float32),
            'sigma_u': np.array([self.sigma_u], dtype=np.float32),
            'time': np.array([self.t/self.T], dtype=np.float32)
        }

    def step(self, action):
        """Execute one step of the environment"""
        if self.t >= self.T:
            raise ValueError("Episode has already ended")

        # Scale PPO's normalized action to market price guess
        scaled_action = action[0] * self.action_scaling
        self.actual_actions.append(scaled_action)

        # Market maker's loss function (negative MSE against true value)
        mm_loss = - (scaled_action - self.v)**2
        self.p = scaled_action

        # Update timestep
        self.t += 1

        if self.t < self.T:
            self.x = self.beta[self.t] * (self.v - self.p)
            self.u = np.random.normal(0, self.sigma_u)
            self.y = self.x + self.u

        terminated = (self.t >= self.T)  # natural termination
        truncated = False  # no time truncation here

        obs = self._get_mm_obs()
        info = {}

        return obs, mm_loss, terminated, truncated, info

# Example usage with Gym interface
print("Testing Kyle model with Gym interface")

env_mm = KyleModelEnvMM()

# Initialize the model

clip_range_schedule = get_linear_fn(start=0.3, end=0.2, end_fraction=0.9)




policy_kwargs = dict(
    net_arch=dict(pi=[128, 128], vf=[128, 128])  # Separate networks
)


model_mm = SAC(
    "MultiInputPolicy",
    env_mm,
    verbose = 1,
    learning_rate = 0.00025
)
# Out:
# Testing Kyle model with Gym interface
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Uzh\project\projectvenv\Lib\site-packages\stable_baselines3\common\utils.py:195: UserWarning: get_linear_fn() is deprecated, please use LinearSchedule() instead
#   warnings.warn("get_linear_fn() is deprecated, please use LinearSchedule() instead")
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model_mm.learn(total_timesteps=5_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -230     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 4714     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 100      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -227     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 145      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 200      |
# | train/             |          |
# |    actor_loss      | 9.87     |
# |    critic_loss     | 102      |
# |    ent_coef        | 0.976    |
# |    ent_coef_loss   | -0.0411  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 99       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -272     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 113      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 300      |
# | train/             |          |
# |    actor_loss      | 14.4     |
# |    critic_loss     | 155      |
# |    ent_coef        | 0.953    |
# |    ent_coef_loss   | -0.071   |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 199      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -257     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 103      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | 18       |
# |    critic_loss     | 160      |
# |    ent_coef        | 0.931    |
# |    ent_coef_loss   | -0.0965  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -263     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 98       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 500      |
# | train/             |          |
# |    actor_loss      | 21.5     |
# |    critic_loss     | 131      |
# |    ent_coef        | 0.911    |
# |    ent_coef_loss   | -0.121   |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 399      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -247     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 95       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 600      |
# | train/             |          |
# |    actor_loss      | 24       |
# |    critic_loss     | 145      |
# |    ent_coef        | 0.892    |
# |    ent_coef_loss   | -0.121   |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 499      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -226     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 94       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 700      |
# | train/             |          |
# |    actor_loss      | 26.3     |
# |    critic_loss     | 127      |
# |    ent_coef        | 0.877    |
# |    ent_coef_loss   | -0.106   |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 599      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -223     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 92       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | 28.8     |
# |    critic_loss     | 129      |
# |    ent_coef        | 0.865    |
# |    ent_coef_loss   | -0.0766  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 699      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -215     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 90       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 900      |
# | train/             |          |
# |    actor_loss      | 30.4     |
# |    critic_loss     | 78.5     |
# |    ent_coef        | 0.856    |
# |    ent_coef_loss   | -0.0619  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 799      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -198     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 87       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1000     |
# | train/             |          |
# |    actor_loss      | 31.5     |
# |    critic_loss     | 70.4     |
# |    ent_coef        | 0.85     |
# |    ent_coef_loss   | -0.0311  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 899      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -185     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 86       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1100     |
# | train/             |          |
# |    actor_loss      | 32       |
# |    critic_loss     | 92.9     |
# |    ent_coef        | 0.847    |
# |    ent_coef_loss   | 0.000684 |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 999      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -173     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 85       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | 32       |
# |    critic_loss     | 72.2     |
# |    ent_coef        | 0.845    |
# |    ent_coef_loss   | -0.00654 |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -169     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 84       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1300     |
# | train/             |          |
# |    actor_loss      | 34       |
# |    critic_loss     | 68.8     |
# |    ent_coef        | 0.843    |
# |    ent_coef_loss   | -0.0129  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 1199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -160     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 83       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1400     |
# | train/             |          |
# |    actor_loss      | 34.2     |
# |    critic_loss     | 54.7     |
# |    ent_coef        | 0.84     |
# |    ent_coef_loss   | -0.0106  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 1299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -153     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 82       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1500     |
# | train/             |          |
# |    actor_loss      | 35.7     |
# |    critic_loss     | 72.3     |
# |    ent_coef        | 0.836    |
# |    ent_coef_loss   | -0.019   |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 1399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -145     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 81       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | 35.8     |
# |    critic_loss     | 60.1     |
# |    ent_coef        | 0.832    |
# |    ent_coef_loss   | -0.0586  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -148     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 81       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 1700     |
# | train/             |          |
# |    actor_loss      | 36.9     |
# |    critic_loss     | 53       |
# |    ent_coef        | 0.827    |
# |    ent_coef_loss   | -0.0357  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 1599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -142     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 80       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 1800     |
# | train/             |          |
# |    actor_loss      | 38       |
# |    critic_loss     | 29.9     |
# |    ent_coef        | 0.821    |
# |    ent_coef_loss   | -0.0448  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 1699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -136     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 80       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 1900     |
# | train/             |          |
# |    actor_loss      | 38.1     |
# |    critic_loss     | 52.7     |
# |    ent_coef        | 0.814    |
# |    ent_coef_loss   | -0.0509  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 1799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -133     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 80       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | 38.9     |
# |    critic_loss     | 59.4     |
# |    ent_coef        | 0.807    |
# |    ent_coef_loss   | -0.0304  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 1899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -129     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 79       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 2100     |
# | train/             |          |
# |    actor_loss      | 38.7     |
# |    critic_loss     | 38.9     |
# |    ent_coef        | 0.799    |
# |    ent_coef_loss   | -0.0486  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 1999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -129     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 79       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 2200     |
# | train/             |          |
# |    actor_loss      | 39.2     |
# |    critic_loss     | 65.2     |
# |    ent_coef        | 0.791    |
# |    ent_coef_loss   | -0.039   |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 2099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -130     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 78       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 2300     |
# | train/             |          |
# |    actor_loss      | 39.3     |
# |    critic_loss     | 59.9     |
# |    ent_coef        | 0.784    |
# |    ent_coef_loss   | -0.0475  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 2199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -130     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 78       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | 41.7     |
# |    critic_loss     | 55.5     |
# |    ent_coef        | 0.775    |
# |    ent_coef_loss   | -0.0829  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -127     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 78       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 2500     |
# | train/             |          |
# |    actor_loss      | 40.8     |
# |    critic_loss     | 48.5     |
# |    ent_coef        | 0.766    |
# |    ent_coef_loss   | -0.0142  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 2399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 77       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 2600     |
# | train/             |          |
# |    actor_loss      | 42.6     |
# |    critic_loss     | 38.9     |
# |    ent_coef        | 0.757    |
# |    ent_coef_loss   | -0.0655  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 2499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -117     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 77       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 2700     |
# | train/             |          |
# |    actor_loss      | 43.2     |
# |    critic_loss     | 50.2     |
# |    ent_coef        | 0.748    |
# |    ent_coef_loss   | -0.0289  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 2599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -108     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 77       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | 44.5     |
# |    critic_loss     | 36.7     |
# |    ent_coef        | 0.738    |
# |    ent_coef_loss   | -0.0691  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 2699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 77       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 2900     |
# | train/             |          |
# |    actor_loss      | 42.7     |
# |    critic_loss     | 57.7     |
# |    ent_coef        | 0.729    |
# |    ent_coef_loss   | -0.0329  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 2799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -95.2    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 77       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 3000     |
# | train/             |          |
# |    actor_loss      | 44.3     |
# |    critic_loss     | 39.7     |
# |    ent_coef        | 0.721    |
# |    ent_coef_loss   | -0.0488  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 2899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -92.2    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 76       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 3100     |
# | train/             |          |
# |    actor_loss      | 44.6     |
# |    critic_loss     | 57.8     |
# |    ent_coef        | 0.713    |
# |    ent_coef_loss   | -0.0463  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 2999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -92      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 76       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | 45.1     |
# |    critic_loss     | 35       |
# |    ent_coef        | 0.705    |
# |    ent_coef_loss   | -0.0479  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -85.5    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 76       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 3300     |
# | train/             |          |
# |    actor_loss      | 45.4     |
# |    critic_loss     | 39       |
# |    ent_coef        | 0.697    |
# |    ent_coef_loss   | -0.0344  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 3199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -83.4    |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 76       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 3400     |
# | train/             |          |
# |    actor_loss      | 46.9     |
# |    critic_loss     | 41.6     |
# |    ent_coef        | 0.689    |
# |    ent_coef_loss   | -0.101   |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 3299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -87.8    |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 76       |
# |    time_elapsed    | 45       |
# |    total_timesteps | 3500     |
# | train/             |          |
# |    actor_loss      | 47.6     |
# |    critic_loss     | 39.9     |
# |    ent_coef        | 0.682    |
# |    ent_coef_loss   | -0.0784  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 3399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -88.9    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 76       |
# |    time_elapsed    | 47       |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | 45.3     |
# |    critic_loss     | 31.6     |
# |    ent_coef        | 0.674    |
# |    ent_coef_loss   | -0.0554  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -90      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 76       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 3700     |
# | train/             |          |
# |    actor_loss      | 48.7     |
# |    critic_loss     | 51.2     |
# |    ent_coef        | 0.666    |
# |    ent_coef_loss   | -0.0363  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 3599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -88.6    |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 76       |
# |    time_elapsed    | 49       |
# |    total_timesteps | 3800     |
# | train/             |          |
# |    actor_loss      | 47.2     |
# |    critic_loss     | 37.8     |
# |    ent_coef        | 0.66     |
# |    ent_coef_loss   | -0.0321  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 3699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -90.7    |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 76       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 3900     |
# | train/             |          |
# |    actor_loss      | 47.3     |
# |    critic_loss     | 36.7     |
# |    ent_coef        | 0.653    |
# |    ent_coef_loss   | -0.0548  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 3799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -90.4    |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 76       |
# |    time_elapsed    | 52       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | 46.6     |
# |    critic_loss     | 40.1     |
# |    ent_coef        | 0.646    |
# |    ent_coef_loss   | -0.0489  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -91.1    |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 75       |
# |    time_elapsed    | 53       |
# |    total_timesteps | 4100     |
# | train/             |          |
# |    actor_loss      | 46       |
# |    critic_loss     | 33.6     |
# |    ent_coef        | 0.64     |
# |    ent_coef_loss   | -0.0432  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 3999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -85.4    |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 75       |
# |    time_elapsed    | 55       |
# |    total_timesteps | 4200     |
# | train/             |          |
# |    actor_loss      | 44.9     |
# |    critic_loss     | 32.5     |
# |    ent_coef        | 0.635    |
# |    ent_coef_loss   | -0.0132  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 4099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -88.4    |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 75       |
# |    time_elapsed    | 56       |
# |    total_timesteps | 4300     |
# | train/             |          |
# |    actor_loss      | 48.8     |
# |    critic_loss     | 50       |
# |    ent_coef        | 0.63     |
# |    ent_coef_loss   | -0.0146  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 4199     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -93.6    |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 75       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | 45.9     |
# |    critic_loss     | 36.3     |
# |    ent_coef        | 0.626    |
# |    ent_coef_loss   | -0.025   |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 4299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -92      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 75       |
# |    time_elapsed    | 59       |
# |    total_timesteps | 4500     |
# | train/             |          |
# |    actor_loss      | 46.6     |
# |    critic_loss     | 35.4     |
# |    ent_coef        | 0.622    |
# |    ent_coef_loss   | -0.00313 |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 4399     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -91      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 75       |
# |    time_elapsed    | 60       |
# |    total_timesteps | 4600     |
# | train/             |          |
# |    actor_loss      | 45.8     |
# |    critic_loss     | 36.7     |
# |    ent_coef        | 0.62     |
# |    ent_coef_loss   | -0.0427  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 4499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -89.8    |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 75       |
# |    time_elapsed    | 62       |
# |    total_timesteps | 4700     |
# | train/             |          |
# |    actor_loss      | 47.5     |
# |    critic_loss     | 41.4     |
# |    ent_coef        | 0.618    |
# |    ent_coef_loss   | -0.0199  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 4599     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -86.1    |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 75       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | 46.5     |
# |    critic_loss     | 36.7     |
# |    ent_coef        | 0.617    |
# |    ent_coef_loss   | 0.0113   |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -83.8    |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 75       |
# |    time_elapsed    | 65       |
# |    total_timesteps | 4900     |
# | train/             |          |
# |    actor_loss      | 46.1     |
# |    critic_loss     | 27.5     |
# |    ent_coef        | 0.616    |
# |    ent_coef_loss   | 0.0234   |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 4799     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | -83.5    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 75       |
# |    time_elapsed    | 66       |
# |    total_timesteps | 5000     |
# | train/             |          |
# |    actor_loss      | 47.6     |
# |    critic_loss     | 33.4     |
# |    ent_coef        | 0.615    |
# |    ent_coef_loss   | -0.0193  |
# |    learning_rate   | 0.00025  |
# |    n_updates       | 4899     |
# ---------------------------------
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
actions = []
prices = []
rewards = []

obs, info = env_mm.reset()
done = False
print(env_mm.v)
print(f"Env x {env_mm.x} Env u {env_mm.u}")
print(f"Obs : {obs}")

while not done:
    action, _ = model_mm.predict(obs)

    obs, reward, terminated, truncated, info = env_mm.step(action)
    action *= 5

    print(f"Env x {env_mm.x} Env u {env_mm.u}")
    print(f"Obs : {obs}")
    print(f"Step: {env_mm.t}, Action: {action}, Reward: {reward}")

    done = terminated or truncated
# Out:
# -1.023316943185034
# Env x -0.20719877210496976 Env u -0.1978538115663974
# Obs : {'y': array([-0.40505257], dtype=float32), 'p': array([0.5], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.], dtype=float32)}
# Env x -0.15448311282198215 Env u -0.23628132400396756
# Obs : {'y': array([-0.39076445], dtype=float32), 'p': array([0.07041156], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.04], dtype=float32)}
# Step: 1, Action: [0.07041156], Reward: -1.196242094039917
# Env x -0.0856245813454883 Env u 0.5340633131827134
# Obs : {'y': array([0.44843873], dtype=float32), 'p': array([-0.44042647], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.08], dtype=float32)}
# Step: 2, Action: [-0.44042647], Reward: -0.339761346578598
# Env x -0.18403756920161204 Env u 1.3085459093481708
# Obs : {'y': array([1.1245084], dtype=float32), 'p': array([0.17931342], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.12], dtype=float32)}
# Step: 3, Action: [0.17931342], Reward: -1.4463199377059937
# Env x -0.21901952774628838 Env u 0.6666951360827428
# Obs : {'y': array([0.44767562], dtype=float32), 'p': array([0.34806252], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.16], dtype=float32)}
# Step: 4, Action: [0.34806252], Reward: -1.8806817531585693
# Env x -0.20831510878224183 Env u 0.0629877079948292
# Obs : {'y': array([-0.1453274], dtype=float32), 'p': array([0.22401512], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.2], dtype=float32)}
# Step: 5, Action: [0.22401512], Reward: -1.5558373928070068
# Env x -0.1412522373153392 Env u -1.6191678575131436
# Obs : {'y': array([-1.7604201], dtype=float32), 'p': array([-0.21627754], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.24], dtype=float32)}
# Step: 6, Action: [-0.21627754], Reward: -0.6513126492500305
# Env x 0.13415569915516917 Env u 0.11835321477493403
# Obs : {'y': array([0.2525089], dtype=float32), 'p': array([-1.7529404], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.28], dtype=float32)}
# Step: 7, Action: [-1.7529404], Reward: -0.5323503613471985
# Env x -0.16091505234859577 Env u 1.9549994389350736
# Obs : {'y': array([1.7940844], dtype=float32), 'p': array([-0.19248635], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.32], dtype=float32)}
# Step: 8, Action: [-0.19248635], Reward: -0.6902795433998108
# Env x -0.5470187144967974 Env u -0.3518277691376777
# Obs : {'y': array([-0.8988465], dtype=float32), 'p': array([1.6499555], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.36], dtype=float32)}
# Step: 9, Action: [1.6499555], Reward: -7.146386623382568
# Env x -0.02791517658177781 Env u -0.30036951922136873
# Obs : {'y': array([-0.3282847], dtype=float32), 'p': array([-0.8946276], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.4], dtype=float32)}
# Step: 10, Action: [-0.8946276], Reward: -0.016560964286327362
# Env x -0.06744152906286817 Env u -0.7627597606929738
# Obs : {'y': array([-0.83020127], dtype=float32), 'p': array([-0.7311499], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.44], dtype=float32)}
# Step: 11, Action: [-0.7311499], Reward: -0.08536159247159958
# Env x -0.1638772553197479 Env u -1.2624805241662422
# Obs : {'y': array([-1.4263577], dtype=float32), 'p': array([-0.35907686], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.48], dtype=float32)}
# Step: 12, Action: [-0.35907686], Reward: -0.4412149488925934
# Env x -0.18427496108963043 Env u 0.5525413080113442
# Obs : {'y': array([0.36826634], dtype=float32), 'p': array([-0.32800287], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.52], dtype=float32)}
# Step: 13, Action: [-0.32800287], Reward: -0.4834617078304291
# Env x -0.3799702195428362 Env u 0.7785667315147353
# Obs : {'y': array([0.39859653], dtype=float32), 'p': array([0.30348718], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.56], dtype=float32)}
# Step: 14, Action: [0.30348718], Reward: -1.7604092359542847
# Env x -0.5885524493244259 Env u -0.13252810652807484
# Obs : {'y': array([-0.72108054], dtype=float32), 'p': array([0.8652955], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.6], dtype=float32)}
# Step: 15, Action: [0.8652955], Reward: -3.566857099533081
# Env x -0.2767643824361824 Env u 0.35698191021720055
# Obs : {'y': array([0.08021753], dtype=float32), 'p': array([-0.21403342], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.64], dtype=float32)}
# Step: 16, Action: [-0.21403342], Reward: -0.6549398899078369
# Env x -0.45101793701646725 Env u 0.18040699009985936
# Obs : {'y': array([-0.27061096], dtype=float32), 'p': array([0.1660192], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.68], dtype=float32)}
# Step: 17, Action: [0.1660192], Reward: -1.414520502090454
# Env x -0.6632687013542705 Env u 1.240391736288367
# Obs : {'y': array([0.57712305], dtype=float32), 'p': array([0.533458], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.72], dtype=float32)}
# Step: 18, Action: [0.533458], Reward: -2.4235482215881348
# Env x -0.8587230833161499 Env u -1.1422865479131614
# Obs : {'y': array([-2.0010097], dtype=float32), 'p': array([0.7402438], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.76], dtype=float32)}
# Step: 19, Action: [0.7402438], Reward: -3.1101465225219727
# Env x -0.5044068028821903 Env u 0.8315198958721288
# Obs : {'y': array([0.3271131], dtype=float32), 'p': array([-0.13777107], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.8], dtype=float32)}
# Step: 20, Action: [-0.13777107], Reward: -0.7841915488243103
# Env x -0.8117267306250854 Env u 0.35915264730831353
# Obs : {'y': array([-0.45257407], dtype=float32), 'p': array([0.15459657], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.84], dtype=float32)}
# Step: 21, Action: [0.15459657], Reward: -1.38748037815094
# Env x -0.310671857502531 Env u 1.0323709535406378
# Obs : {'y': array([0.7216991], dtype=float32), 'p': array([-0.67002743], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.88], dtype=float32)}
# Step: 22, Action: [-0.67002743], Reward: -0.1248135045170784
# Env x -1.3609110064388579 Env u 0.05541985885277325
# Obs : {'y': array([-1.3054911], dtype=float32), 'p': array([0.07605672], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.92], dtype=float32)}
# Step: 23, Action: [0.07605672], Reward: -1.2086225748062134
# Env x -1.0416948031816373 Env u 0.6132638496604736
# Obs : {'y': array([-0.42843094], dtype=float32), 'p': array([-0.55631757], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([0.96], dtype=float32)}
# Step: 24, Action: [-0.55631757], Reward: -0.21808844804763794
# Env x -1.0416948031816373 Env u 0.6132638496604736
# Obs : {'y': array([-0.42843094], dtype=float32), 'p': array([-0.40841788], dtype=float32), 'sigma_v': array([2.], dtype=float32), 'sigma_u': array([1.], dtype=float32), 'time': array([1.], dtype=float32)}
# Step: 25, Action: [-0.40841788], Reward: -0.3781009018421173
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def evaluate_agent_actions_multiperiod_mm(model, env, action_scaling=5):
    obs, info = env.reset()

    steps = env.T
    optimal_insider_actions = np.zeros((steps))
    optimal_market_maker_actions = np.zeros((steps))

    trained_insider_actions = np.zeros((steps))
    trained_market_maker_actions = np.zeros((steps))

    values = np.linspace(1, steps, steps)

    p0 = env.p0
    v = env.v

    beta, lmbd = solve_kyle_model_mine(steps, env.sigma_v, env.sigma_u)

    total_reward_model = np.zeros((steps))
    total_reward_optimal = np.zeros((steps))

        

    for i in range(len(values)):
        
        trained_insider_actions[i] = equilibrium_insider_action(v, env.p, beta[i])
        optimal_insider_actions[i] = equilibrium_insider_action(v, p0, beta[i])
        u = env.u
        y = optimal_insider_actions[i] + u
        

        action, _ = model_mm.predict(obs, deterministic=True)
        trained_market_maker_actions[i] = action * action_scaling
        optimal_market_maker_actions[i] = equilibrium_market_maker_action(y, p0, lmbd[i])
        p0 = lmbd[i] * y + p0
        obs, reward, terminated, truncated, info = env_mm.step(action)

        

    env.reset()

    # plot: 2 subplots. one for insider (values vs action) and one for market maker (order vs action)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
    
    # Insider subplot
    ax1.plot(values, optimal_insider_actions, label="Optimal", linestyle='--')
    ax1.plot(values, trained_insider_actions, label="Trained", linestyle='-')
    ax1.axvline(x=env.p0, color='black', linestyle=':', alpha=0.5)
    ax1.axhline(y=0, color='black', linestyle=':', alpha=0.5)
    ax1.set_title("Insider Action")
    ax1.set_xlabel("Timestep t")
    ax1.set_ylabel("Action x")
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # Market Maker subplot
    ax2.plot(values, optimal_market_maker_actions, label="Optimal", linestyle='--')
    ax2.plot(values, trained_market_maker_actions, label="Trained", linestyle='-')
    ax2.axvline(x=0, color='black', linestyle=':', alpha=0.5)
    ax2.axhline(y=env.p0, color='black', linestyle=':', alpha=0.5)
    ax2.set_title("Market Maker Action")
    ax2.set_xlabel("Timestep t")
    ax2.set_ylabel("Price p")
    ax2.legend()
    ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
evaluate_agent_actions_multiperiod_mm(model_mm, env_mm)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
